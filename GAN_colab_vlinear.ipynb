# %%
# !pip install pytorch-fid
# !pip install wget
# !pip install unrar
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-fid
#   Downloading pytorch-fid-0.2.1.tar.gz (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (7.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.4.1)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.11.0+cu113)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.0.1->pytorch-fid) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.2.2->pytorch-fid) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (3.0.4)
# Building wheels for collected packages: pytorch-fid
#   Building wheel for pytorch-fid (setup.py) ... done
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.2.1-py3-none-any.whl size=14835 sha256=97e3249e22f5710b28125c5d7437952d5136dbeb231df4389a30b0f6d7362250
#   Stored in directory: /root/.cache/pip/wheels/24/ac/03/c5634775c8a64f702343ef5923278f8d3bb8c651debc4a6890
# Successfully built pytorch-fid
# Installing collected packages: pytorch-fid
# Successfully installed pytorch-fid-0.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=c711be04857ffa6bafa97716a8447d0166df0db8e3a0984f27bd697d3e50597a
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unrar
#   Downloading unrar-0.4-py3-none-any.whl (25 kB)
# Installing collected packages: unrar
# Successfully installed unrar-0.4

# %%
import os
import shutil
import cupy as cp
import numpy
import math
import matplotlib.pyplot as plt
import torch
from torch import optim
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.utils import make_grid, save_image
from torchvision.datasets import ImageFolder
import torchvision.transforms as T
from torch.autograd import Variable
from pytorch_fid import inception
from torchvision.models.inception import inception_v3
from PIL import Image
from scipy import linalg
from scipy.stats import entropy
import wget

# %%
os.mkdir('unfiltered')
data_path = r'./unfiltered'
os.mkdir('filtered')
target_path= r'./filtered'
os.mkdir('examples')
os.mkdir('trained_models')

# %%
URL = "https://drive.google.com/u/0/uc?id=1TQQuT60bddyeGBVfwNOk6nxYavxQdZJD&export=download&confirm=t" 
# !wget -O thecarconnectionpicturedataset.rar --no-check-certificate "$URL"
# Out:
# --2022-05-25 19:01:25--  https://drive.google.com/u/0/uc?id=1TQQuT60bddyeGBVfwNOk6nxYavxQdZJD&export=download&confirm=t
# Resolving drive.google.com (drive.google.com)... 74.125.142.100, 74.125.142.139, 74.125.142.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.142.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://drive.google.com/uc?id=1TQQuT60bddyeGBVfwNOk6nxYavxQdZJD&export=download&confirm=t [following]
# --2022-05-25 19:01:25--  https://drive.google.com/uc?id=1TQQuT60bddyeGBVfwNOk6nxYavxQdZJD&export=download&confirm=t
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0o-70-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1hb1i207da3img5fjlj24dkgcbala14o/1653505275000/01153971418670501229/*/1TQQuT60bddyeGBVfwNOk6nxYavxQdZJD?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2022-05-25 19:01:25--  https://doc-0o-70-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/1hb1i207da3img5fjlj24dkgcbala14o/1653505275000/01153971418670501229/*/1TQQuT60bddyeGBVfwNOk6nxYavxQdZJD?e=download
# Resolving doc-0o-70-docs.googleusercontent.com (doc-0o-70-docs.googleusercontent.com)... 108.177.98.132, 2607:f8b0:400e:c06::84
# Connecting to doc-0o-70-docs.googleusercontent.com (doc-0o-70-docs.googleusercontent.com)|108.177.98.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 714479682 (681M) [application/rar]
# Saving to: ‘thecarconnectionpicturedataset.rar’
#
# thecarconnectionpic 100%[===================>] 681.38M   271MB/s    in 2.5s
#
# 2022-05-25 19:01:28 (271 MB/s) - ‘thecarconnectionpicturedataset.rar’ saved [714479682/714479682]

# %%
# !unrar x "thecarconnectionpicturedataset.rar" "unfiltered/"
# Out:
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
listOfFiles = os.listdir(data_path)
car_types= ['Convertible','Pickup','Station Wagon','4dr','3dr','2dr','SUV','Van']  # reszta to 'nan'
car_dictionary = dict.fromkeys(car_types)
for type_of_car in car_types:
    str_match = [s for s in listOfFiles if type_of_car+"_" in s]
    car_dictionary[type_of_car] = len(str_match)
    # ponizej tworzenie folderow z posortowanymi juz zdjeciami typow, czyli tzw. klas
    os.mkdir(os.path.join(target_path,type_of_car))
    target_dir = os.path.join(target_path,type_of_car)
    for fname in str_match:
        # przenoszenie plikow do wlasciwych folderow
        shutil.move(os.path.join(data_path,fname), target_dir)

# %%
cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if cuda else torch.LongTensor

cuda
# Out:
# True

# %%
## inicjalizacja parametrow
number_of_classes = len(car_types)
number_of_epochs = 6

image_size_width = 320
image_size_height = 200

image_size_width = 250
image_size_height = 250

image_size=(image_size_width,image_size_height)
channels = 3 # RGB
img_shape_tuple = (channels, image_size_width, image_size_height)
img_shape = cp.array([channels, image_size_width, image_size_height])

batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)
latent_size = 128  # rozmiar wektora wejsciowego do generatora

# rozmiar zdjec 320x213 pikseli, niektore na x240 lub x160 piskeli, dlatego niech bedzie 320x200 krakowskim targiem
# no chyba że musimy mieć kwadrat, jest tak podanych wiele przykladow i nie wiem, 
# czy przypadkiem wtedy nie ma siec latwiej sobie podzielic obrazu jesli oba rozmiary sa rowne

# z czego korzystam?
# 1) https://jovian.ai/tvscitechtalk/car-gan
# 2) https://github.com/ozanciga/gans-with-pytorch/blob/master/cgan/cgan.py

# ten poniżej kod bardziej do mnie przemawia jeśli chodzi o definicje dyskryminatora i generatora
# 3) https://github.com/eriklindernoren/PyTorch-GAN/blob/36d3c77e5ff20ebe0aeefd322326a134a279b93e/implementations/cgan/cgan.py#L189

# konwersja obrazu do tensora z odpowiednimi warunkami 
train_ds = ImageFolder(target_path, transform=T.Compose([
    T.Resize((image_size_width,image_size_height)),
    T.ToTensor(),
    T.Normalize(*stats)]))

## wykorzystanie części zbioru
train_ds.samples = [train_ds.samples[idx] for idx in range(5000)]
train_ds.targets = [train_ds.targets[idx] for idx in range(5000)]

# zbiór treningowy
train_dl = DataLoader(train_ds, batch_size, shuffle=True)

# %%
## pokazanie przykladowego batcha ze zdjeciami samochodow

def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

show_batch(train_dl)

# %%
## klasa generatora

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.label_emb = nn.Embedding(number_of_classes, number_of_classes,device=torch.device('cuda'))

        def block(in_feat, out_feat, normalize=True):
                # layers = [nn.Linear(in_feat, out_feat)]
                layers = [nn.Linear(in_feat, out_feat)]
                if normalize:
                    layers.append(nn.BatchNorm1d(out_feat, 0.8))
                layers.append(nn.LeakyReLU(0.2, inplace=True))
                return layers

        self.model = nn.Sequential(
            # nn.Linear(latent_size + number_of_classes, 128),
            # nn.LeakyReLU(0.2, inplace=True),
            # nn.Linear(128, 256),
            # nn.BatchNorm1d(256, 0.5),
            # nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(latent_size + number_of_classes, 256),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(256, 512),
            nn.BatchNorm1d(512, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 1024),
            nn.BatchNorm1d(1024, 0.8),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(1024, int(cp.prod(img_shape))),
            nn.Tanh()
        )

    def forward(self, noise, labels):
        # Concatenate label embedding and image to produce input
        gen_input = torch.cat((self.label_emb(labels), noise), -1)
        img = self.model(gen_input.cuda())
        img = img.view(img.size(0), *img_shape_tuple)
        return img

# %%
## klasa dyskryminatora - póki co idea skopiowana z linku 3)
class Discriminator(nn.Module):
    def __init__(self):
            super(Discriminator, self).__init__()

            self.label_emb = nn.Embedding(number_of_classes, number_of_classes,device=torch.device('cuda'))

            # self.model = nn.Sequential(
                
            #     nn.Conv2d(3, 250, kernel_size=5, stride=10, padding=1, bias=False),
            #     nn.BatchNorm2d(250),
            #     nn.LeakyReLU(0.2, inplace=True),
                
                
            #     nn.Conv2d(250, 500, kernel_size=5, stride=10, padding=1, bias=False),
            #     nn.BatchNorm2d(500),
            #     nn.LeakyReLU(0.2, inplace=True),
              
            #     nn.Conv2d(500, 1, kernel_size=5, stride=10, padding=0, bias=False), 

            # #     # nn.Conv2d(1000, 2000, kernel_size=5, stride=2, padding=1, bias=False),
            # #     # nn.BatchNorm2d(2000),
            # #     # nn.LeakyReLU(0.2, inplace=True),
                

            # #     # nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
            # #     # # nn.BatchNorm2d(512),
            # #     # nn.LeakyReLU(0.2, inplace=True),
            # #     # # out: 512 x 4 x 4

            # #     # nn.Conv2d(2000, 1, kernel_size=5, stride=1, padding=0, bias=False),               

            #     nn.Flatten(),
            #     nn.Sigmoid()
            # )

            self.model = nn.Sequential(
                nn.Linear(number_of_classes+ int(cp.prod(img_shape)), 512),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Linear(512, 512),
                nn.Dropout(0.4),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Linear(512, 512),
                nn.Dropout(0.4),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Linear(512, 1),
                nn.Sigmoid()
            )

            # self.model = nn.Sequential(
            #     nn.Linear(number_of_classes+ int(cp.prod(img_shape)), 1024),
            #     nn.LeakyReLU(0.4, inplace=True),
            #     nn.Linear(1024, 512),
            #     nn.Dropout(0.4),
            #     nn.LeakyReLU(0.2, inplace=True),
            #     nn.Linear(512, 512),
            #     nn.Dropout(0.4),
            #     nn.LeakyReLU(0.2, inplace=True),
            #     nn.Linear(512, 256),
            #     nn.Dropout(0.4),
            #     # nn.LeakyReLU(0.2, inplace=True),
            #     # nn.Linear(256, 256),
            #     # nn.Dropout(0.4),
            #     nn.LeakyReLU(0.2, inplace=True),
            #     nn.Linear(256, 1),
            #     nn.Sigmoid()
            # )

            self.embe= nn.Sequential(
            nn.Linear(8, 4),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(4, 2),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(2, 1)
            )

    def forward(self, img, labels):
        # Concatenate label embedding and image to produce input
        # print(self.label_emb(labels).size())
        # print(type(self.label_emb(labels)))
      
        # embe_linear=self.embe(self.label_emb(labels).cuda())
        # print(embe_linear.size())

        d_in = torch.cat((img.view(img.size(0), -1), self.label_emb(labels)), -1)
        validity = self.model(d_in)
        # # d_in = torch.cat((img.view(img.size(0), -1), self.label_embedding(labels)), -1)
        # # d_n = d_in.view(1,d_in.size(0), d_in.size(1),1)
        # # print(d_n.size())
        # # d_n = d_in.view(d_in.size(0), d_in.size(1),1)
        # # print(d_n.size())
        # # d_n = d_in.view(1,1,d_in.size(0), d_in.size(1))
        # d_n = img.view(batch_size,3,250, 250)
        # print(d_n.size())
        # # validity = self.model(d_in.view(d_in.size(0), d_in.size(1), 1, 1))
        # validity = self.model(d_n)
        return validity

# %%
# jako funkcja straty binarna entropia krzyzowa
fun_loss = nn.BCELoss()

device=torch.device('cuda')
# inicjalizacja generatora i dyskyminatora
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# wykorzystanie algorytmu Adam do optymalizacji procesu uczenia metodą spadku gradientu
b1=0.5
b2=0.999
lrate=0.0002
#lrate=0.0005
optimizer_D = optim.Adam(discriminator.parameters(), lr=lrate, betas=(b1, b2))
optimizer_G = optim.Adam(generator.parameters(), lr=lrate, betas=(b1, b2))

# %%
def sample_image(n_row, batches_done):
    """zapisywanie obrazów wygenerowanych przez klasę generatora"""
    # losowy szum
    z = Variable(FloatTensor(cp.random.normal(0, 1, (n_row ** 2, latent_size))))
    # przygotowanie etykiet klas
    labels = cp.array([num for _ in range(n_row) for num in range(n_row)])
    labels = Variable(LongTensor(labels))
    # wygenerowanie obrazow
    gen_imgs = generator(z, labels)
    save_image(gen_imgs.data, "./examples/%d.png" % batches_done, nrow=n_row, normalize=True)

# %%
# ----------
#  Training
# ----------
d_loss_it=[]
g_loss_it=[]

for epoch in range(number_of_epochs):
    for i, (imgs, labels) in enumerate(train_dl):

        batch_size = imgs.shape[0]

        # Adversarial ground truths
        valid = Variable(FloatTensor(batch_size, 1).fill_(1.0), requires_grad=False)
        fake = Variable(FloatTensor(batch_size, 1).fill_(0.0), requires_grad=False)

        # Configure input
        real_imgs = Variable(imgs.type(FloatTensor))
        labels = Variable(labels.type(LongTensor))

        # -----------------
        #  Train Generator
        # -----------------

        optimizer_G.zero_grad()

        # Sample noise and labels as generator input
        z = Variable(FloatTensor(cp.random.normal(0, 1, (batch_size, latent_size))))
        gen_labels = Variable(LongTensor(cp.random.randint(0, number_of_classes, batch_size)))

        # Generate a batch of images
        gen_imgs = generator(z, gen_labels)
        # Loss measures generator's ability to fool the discriminator
        validity = discriminator(gen_imgs, gen_labels)
        g_loss = fun_loss(validity, valid)

        g_loss.backward()
        optimizer_G.step()

        # ---------------------
        #  Train Discriminator
        # ---------------------

        optimizer_D.zero_grad()

        # Loss for real images
        validity_real = discriminator(real_imgs, labels)
        d_real_loss = fun_loss(validity_real, valid)

        # Loss for fake images
        validity_fake = discriminator(gen_imgs.detach(), gen_labels)
        d_fake_loss = fun_loss(validity_fake, fake)

        # Total discriminator loss
        d_loss = (d_real_loss + d_fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()

        print(
            "[Epoch %d/%d] [Batch %d/%d] [D loss: %f] [G loss: %f]"
            % (epoch + 1, number_of_epochs, i + 1, len(train_dl), d_loss.item(), g_loss.item())
        )

        d_loss_it.append(d_loss.item())
        g_loss_it.append(g_loss.item())

        batches_done = epoch * len(train_dl) + i
        if batches_done % 20 == 0:
            sample_image(n_row=5, batches_done=batches_done)


torch.cuda.empty_cache()
# Out:
# [Epoch 1/6] [Batch 1/40] [D loss: 0.705293] [G loss: 0.722443]
# [Epoch 1/6] [Batch 2/40] [D loss: 0.611266] [G loss: 0.715252]
# [Epoch 1/6] [Batch 3/40] [D loss: 0.425402] [G loss: 0.571474]
# [Epoch 1/6] [Batch 4/40] [D loss: 0.306042] [G loss: 1.057742]
# [Epoch 1/6] [Batch 5/40] [D loss: 0.703020] [G loss: 0.294414]
# [Epoch 1/6] [Batch 6/40] [D loss: 0.190368] [G loss: 1.386949]
# [Epoch 1/6] [Batch 7/40] [D loss: 1.195958] [G loss: 1.704827]
# [Epoch 1/6] [Batch 8/40] [D loss: 9.336444] [G loss: 0.000052]
# [Epoch 1/6] [Batch 9/40] [D loss: 2.874892] [G loss: 0.007573]
# [Epoch 1/6] [Batch 10/40] [D loss: 0.312495] [G loss: 0.874586]
# [Epoch 1/6] [Batch 11/40] [D loss: 2.430069] [G loss: 2.714922]
# [Epoch 1/6] [Batch 12/40] [D loss: 0.555941] [G loss: 0.402425]
# [Epoch 1/6] [Batch 13/40] [D loss: 0.517419] [G loss: 0.449769]
# [Epoch 1/6] [Batch 14/40] [D loss: 0.457577] [G loss: 0.552060]
# [Epoch 1/6] [Batch 15/40] [D loss: 0.412944] [G loss: 0.580503]
# [Epoch 1/6] [Batch 16/40] [D loss: 0.233954] [G loss: 1.216195]
# [Epoch 1/6] [Batch 17/40] [D loss: 2.456565] [G loss: 2.521920]
# [Epoch 1/6] [Batch 18/40] [D loss: 14.523000] [G loss: 0.000007]
# [Epoch 1/6] [Batch 19/40] [D loss: 4.250300] [G loss: 0.000836]
# [Epoch 1/6] [Batch 20/40] [D loss: 0.833821] [G loss: 0.291298]
# [Epoch 1/6] [Batch 21/40] [D loss: 3.410204] [G loss: 3.749366]
# [Epoch 1/6] [Batch 22/40] [D loss: 0.591796] [G loss: 0.428078]
# [Epoch 1/6] [Batch 23/40] [D loss: 0.412013] [G loss: 0.619647]
# [Epoch 1/6] [Batch 24/40] [D loss: 0.291480] [G loss: 1.103694]
# [Epoch 1/6] [Batch 25/40] [D loss: 0.133916] [G loss: 1.557073]
# [Epoch 1/6] [Batch 26/40] [D loss: 0.176337] [G loss: 1.378934]
# [Epoch 1/6] [Batch 27/40] [D loss: 0.458959] [G loss: 0.755993]
# [Epoch 1/6] [Batch 28/40] [D loss: 3.025804] [G loss: 2.137226]
# [Epoch 1/6] [Batch 29/40] [D loss: 3.543516] [G loss: 0.003084]
# [Epoch 1/6] [Batch 30/40] [D loss: 1.336300] [G loss: 0.096879]
# [Epoch 1/6] [Batch 31/40] [D loss: 0.605119] [G loss: 0.935800]
# [Epoch 1/6] [Batch 32/40] [D loss: 0.382148] [G loss: 0.801462]
# [Epoch 1/6] [Batch 33/40] [D loss: 0.373378] [G loss: 0.703057]
# [Epoch 1/6] [Batch 34/40] [D loss: 0.275513] [G loss: 1.005507]
# [Epoch 1/6] [Batch 35/40] [D loss: 0.265890] [G loss: 1.394388]
# [Epoch 1/6] [Batch 36/40] [D loss: 0.268736] [G loss: 1.202344]
# [Epoch 1/6] [Batch 37/40] [D loss: 0.255415] [G loss: 0.977962]
# [Epoch 1/6] [Batch 38/40] [D loss: 0.174512] [G loss: 1.403286]
# [Epoch 1/6] [Batch 39/40] [D loss: 0.213966] [G loss: 1.692684]
# [Epoch 1/6] [Batch 40/40] [D loss: 0.175011] [G loss: 1.247717]
# [Epoch 2/6] [Batch 1/40] [D loss: 0.170601] [G loss: 1.357859]
# [Epoch 2/6] [Batch 2/40] [D loss: 0.269463] [G loss: 1.588121]
# [Epoch 2/6] [Batch 3/40] [D loss: 0.403244] [G loss: 0.624521]
# [Epoch 2/6] [Batch 4/40] [D loss: 0.310667] [G loss: 0.780269]
# [Epoch 2/6] [Batch 5/40] [D loss: 0.277885] [G loss: 1.272051]
# [Epoch 2/6] [Batch 6/40] [D loss: 0.308691] [G loss: 0.846098]
# [Epoch 2/6] [Batch 7/40] [D loss: 0.343084] [G loss: 0.725331]
# [Epoch 2/6] [Batch 8/40] [D loss: 0.284247] [G loss: 0.936035]
# [Epoch 2/6] [Batch 9/40] [D loss: 0.298311] [G loss: 0.906282]
# [Epoch 2/6] [Batch 10/40] [D loss: 0.312729] [G loss: 0.901312]
# [Epoch 2/6] [Batch 11/40] [D loss: 0.372108] [G loss: 0.732298]
# [Epoch 2/6] [Batch 12/40] [D loss: 0.300680] [G loss: 0.859134]
# [Epoch 2/6] [Batch 13/40] [D loss: 0.323174] [G loss: 1.084995]
# [Epoch 2/6] [Batch 14/40] [D loss: 0.337399] [G loss: 0.731645]
# [Epoch 2/6] [Batch 15/40] [D loss: 0.242444] [G loss: 0.947612]
# [Epoch 2/6] [Batch 16/40] [D loss: 0.260827] [G loss: 1.332032]
# [Epoch 2/6] [Batch 17/40] [D loss: 0.272972] [G loss: 0.917714]
# [Epoch 2/6] [Batch 18/40] [D loss: 0.253596] [G loss: 1.146114]
# [Epoch 2/6] [Batch 19/40] [D loss: 0.258119] [G loss: 0.980670]
# [Epoch 2/6] [Batch 20/40] [D loss: 0.311530] [G loss: 0.952211]
# [Epoch 2/6] [Batch 21/40] [D loss: 0.328651] [G loss: 0.758309]
# [Epoch 2/6] [Batch 22/40] [D loss: 0.431250] [G loss: 1.368927]
# [Epoch 2/6] [Batch 23/40] [D loss: 0.744906] [G loss: 0.284207]
# [Epoch 2/6] [Batch 24/40] [D loss: 0.377415] [G loss: 0.664457]
# [Epoch 2/6] [Batch 25/40] [D loss: 0.210342] [G loss: 1.086114]
# [Epoch 2/6] [Batch 26/40] [D loss: 0.130965] [G loss: 1.573922]
# [Epoch 2/6] [Batch 27/40] [D loss: 0.103796] [G loss: 1.896334]
# [Epoch 2/6] [Batch 28/40] [D loss: 0.224660] [G loss: 1.766180]
# [Epoch 2/6] [Batch 29/40] [D loss: 0.200650] [G loss: 1.160766]
# [Epoch 2/6] [Batch 30/40] [D loss: 0.238204] [G loss: 1.011769]
# [Epoch 2/6] [Batch 31/40] [D loss: 0.214112] [G loss: 1.105994]
# [Epoch 2/6] [Batch 32/40] [D loss: 0.156735] [G loss: 1.336577]
# [Epoch 2/6] [Batch 33/40] [D loss: 0.502575] [G loss: 1.591777]
# [Epoch 2/6] [Batch 34/40] [D loss: 2.192976] [G loss: 0.161621]
# [Epoch 2/6] [Batch 35/40] [D loss: 1.234992] [G loss: 0.203965]
# [Epoch 2/6] [Batch 36/40] [D loss: 0.441675] [G loss: 0.609795]
# [Epoch 2/6] [Batch 37/40] [D loss: 1.481291] [G loss: 1.545280]
# [Epoch 2/6] [Batch 38/40] [D loss: 1.060577] [G loss: 0.159142]
# [Epoch 2/6] [Batch 39/40] [D loss: 0.896685] [G loss: 0.211113]
# [Epoch 2/6] [Batch 40/40] [D loss: 0.387891] [G loss: 0.621677]
# [Epoch 3/6] [Batch 1/40] [D loss: 0.793296] [G loss: 1.237786]
# [Epoch 3/6] [Batch 2/40] [D loss: 0.703878] [G loss: 0.295118]
# [Epoch 3/6] [Batch 3/40] [D loss: 0.564530] [G loss: 0.422725]
# [Epoch 3/6] [Batch 4/40] [D loss: 0.370167] [G loss: 0.654668]
# [Epoch 3/6] [Batch 5/40] [D loss: 0.292798] [G loss: 0.930590]
# [Epoch 3/6] [Batch 6/40] [D loss: 0.210143] [G loss: 1.123774]
# [Epoch 3/6] [Batch 7/40] [D loss: 0.205686] [G loss: 1.305725]
# [Epoch 3/6] [Batch 8/40] [D loss: 0.210590] [G loss: 1.159765]
# [Epoch 3/6] [Batch 9/40] [D loss: 0.213336] [G loss: 1.085115]
# [Epoch 3/6] [Batch 10/40] [D loss: 0.202139] [G loss: 1.180868]
# [Epoch 3/6] [Batch 11/40] [D loss: 0.313094] [G loss: 1.168530]
# [Epoch 3/6] [Batch 12/40] [D loss: 0.452880] [G loss: 0.585266]
# [Epoch 3/6] [Batch 13/40] [D loss: 0.491518] [G loss: 0.548662]
# [Epoch 3/6] [Batch 14/40] [D loss: 0.880326] [G loss: 0.730924]
# [Epoch 3/6] [Batch 15/40] [D loss: 1.202439] [G loss: 0.216952]
# [Epoch 3/6] [Batch 16/40] [D loss: 0.676125] [G loss: 0.422440]
# [Epoch 3/6] [Batch 17/40] [D loss: 0.730475] [G loss: 1.698058]
# [Epoch 3/6] [Batch 18/40] [D loss: 0.608773] [G loss: 0.458590]
# [Epoch 3/6] [Batch 19/40] [D loss: 0.507042] [G loss: 0.619885]
# [Epoch 3/6] [Batch 20/40] [D loss: 0.352327] [G loss: 0.949442]
# [Epoch 3/6] [Batch 21/40] [D loss: 0.380414] [G loss: 1.086138]
# [Epoch 3/6] [Batch 22/40] [D loss: 0.448195] [G loss: 0.601100]
# [Epoch 3/6] [Batch 23/40] [D loss: 0.545125] [G loss: 0.665025]
# [Epoch 3/6] [Batch 24/40] [D loss: 0.619228] [G loss: 0.577076]
# [Epoch 3/6] [Batch 25/40] [D loss: 0.495362] [G loss: 0.832124]
# [Epoch 3/6] [Batch 26/40] [D loss: 0.341773] [G loss: 1.373062]
# [Epoch 3/6] [Batch 27/40] [D loss: 0.410490] [G loss: 0.886567]
# [Epoch 3/6] [Batch 28/40] [D loss: 0.569952] [G loss: 0.749278]
# [Epoch 3/6] [Batch 29/40] [D loss: 0.500123] [G loss: 0.581042]
# [Epoch 3/6] [Batch 30/40] [D loss: 0.365520] [G loss: 1.796028]
# [Epoch 3/6] [Batch 31/40] [D loss: 0.854376] [G loss: 0.324541]
# [Epoch 3/6] [Batch 32/40] [D loss: 0.659676] [G loss: 0.464250]
# [Epoch 3/6] [Batch 33/40] [D loss: 0.418576] [G loss: 0.972996]
# [Epoch 3/6] [Batch 34/40] [D loss: 0.519599] [G loss: 0.540822]
# [Epoch 3/6] [Batch 35/40] [D loss: 0.417759] [G loss: 0.799596]
# [Epoch 3/6] [Batch 36/40] [D loss: 0.339934] [G loss: 0.822108]
# [Epoch 3/6] [Batch 37/40] [D loss: 0.362016] [G loss: 0.880354]
# [Epoch 3/6] [Batch 38/40] [D loss: 0.402273] [G loss: 0.767889]
# [Epoch 3/6] [Batch 39/40] [D loss: 0.339105] [G loss: 1.182359]
# [Epoch 3/6] [Batch 40/40] [D loss: 0.507185] [G loss: 0.722786]
# [Epoch 4/6] [Batch 1/40] [D loss: 0.772211] [G loss: 0.368202]
# [Epoch 4/6] [Batch 2/40] [D loss: 0.354309] [G loss: 0.883502]
# [Epoch 4/6] [Batch 3/40] [D loss: 0.588314] [G loss: 1.269059]
# [Epoch 4/6] [Batch 4/40] [D loss: 0.596668] [G loss: 0.480186]
# [Epoch 4/6] [Batch 5/40] [D loss: 0.505355] [G loss: 0.541792]
# [Epoch 4/6] [Batch 6/40] [D loss: 0.449604] [G loss: 0.793542]
# [Epoch 4/6] [Batch 7/40] [D loss: 0.354794] [G loss: 0.795392]
# [Epoch 4/6] [Batch 8/40] [D loss: 0.423621] [G loss: 0.706759]
# [Epoch 4/6] [Batch 9/40] [D loss: 0.409439] [G loss: 0.720708]
# [Epoch 4/6] [Batch 10/40] [D loss: 0.405747] [G loss: 0.719169]
# [Epoch 4/6] [Batch 11/40] [D loss: 0.433115] [G loss: 0.707615]
# [Epoch 4/6] [Batch 12/40] [D loss: 0.424544] [G loss: 0.791682]
# [Epoch 4/6] [Batch 13/40] [D loss: 0.352088] [G loss: 0.863450]
# [Epoch 4/6] [Batch 14/40] [D loss: 0.379800] [G loss: 0.942901]
# [Epoch 4/6] [Batch 15/40] [D loss: 0.438254] [G loss: 0.635109]
# [Epoch 4/6] [Batch 16/40] [D loss: 0.432552] [G loss: 0.985763]
# [Epoch 4/6] [Batch 17/40] [D loss: 0.439408] [G loss: 0.734407]
# [Epoch 4/6] [Batch 18/40] [D loss: 0.498091] [G loss: 0.937483]
# [Epoch 4/6] [Batch 19/40] [D loss: 0.635294] [G loss: 0.420351]
# [Epoch 4/6] [Batch 20/40] [D loss: 0.454568] [G loss: 0.744515]
# [Epoch 4/6] [Batch 21/40] [D loss: 0.414609] [G loss: 1.304519]
# [Epoch 4/6] [Batch 22/40] [D loss: 0.362908] [G loss: 0.848106]
# [Epoch 4/6] [Batch 23/40] [D loss: 0.340473] [G loss: 1.005151]
# [Epoch 4/6] [Batch 24/40] [D loss: 0.284284] [G loss: 0.981155]
# [Epoch 4/6] [Batch 25/40] [D loss: 0.285850] [G loss: 1.274557]
# [Epoch 4/6] [Batch 26/40] [D loss: 0.339474] [G loss: 1.036355]
# [Epoch 4/6] [Batch 27/40] [D loss: 0.386809] [G loss: 0.857275]
# [Epoch 4/6] [Batch 28/40] [D loss: 0.312261] [G loss: 1.372598]
# [Epoch 4/6] [Batch 29/40] [D loss: 0.253449] [G loss: 0.972744]
# [Epoch 4/6] [Batch 30/40] [D loss: 0.227604] [G loss: 1.402118]
# [Epoch 4/6] [Batch 31/40] [D loss: 0.369786] [G loss: 0.895303]
# [Epoch 4/6] [Batch 32/40] [D loss: 0.428244] [G loss: 0.895040]
# [Epoch 4/6] [Batch 33/40] [D loss: 0.585756] [G loss: 0.434210]
# [Epoch 4/6] [Batch 34/40] [D loss: 0.229318] [G loss: 1.368057]
# [Epoch 4/6] [Batch 35/40] [D loss: 0.384772] [G loss: 1.803604]
# [Epoch 4/6] [Batch 36/40] [D loss: 0.574763] [G loss: 0.461036]
# [Epoch 4/6] [Batch 37/40] [D loss: 0.462854] [G loss: 0.582763]
# [Epoch 4/6] [Batch 38/40] [D loss: 0.303993] [G loss: 0.891612]
# [Epoch 4/6] [Batch 39/40] [D loss: 0.413481] [G loss: 1.108103]
# [Epoch 4/6] [Batch 40/40] [D loss: 0.455731] [G loss: 0.732758]
# [Epoch 5/6] [Batch 1/40] [D loss: 0.552886] [G loss: 0.588489]
# [Epoch 5/6] [Batch 2/40] [D loss: 0.359475] [G loss: 1.066309]
# [Epoch 5/6] [Batch 3/40] [D loss: 0.372847] [G loss: 1.081370]
# [Epoch 5/6] [Batch 4/40] [D loss: 0.434430] [G loss: 0.736860]
# [Epoch 5/6] [Batch 5/40] [D loss: 0.608583] [G loss: 1.441563]
# [Epoch 5/6] [Batch 6/40] [D loss: 2.663307] [G loss: 0.531052]
# [Epoch 5/6] [Batch 7/40] [D loss: 0.439845] [G loss: 0.854247]
# [Epoch 5/6] [Batch 8/40] [D loss: 1.196597] [G loss: 3.010514]
# [Epoch 5/6] [Batch 9/40] [D loss: 1.299959] [G loss: 0.899132]
# [Epoch 5/6] [Batch 10/40] [D loss: 0.444394] [G loss: 0.779425]
# [Epoch 5/6] [Batch 11/40] [D loss: 0.982247] [G loss: 1.613472]
# [Epoch 5/6] [Batch 12/40] [D loss: 0.912017] [G loss: 0.246189]
# [Epoch 5/6] [Batch 13/40] [D loss: 0.697941] [G loss: 0.329664]
# [Epoch 5/6] [Batch 14/40] [D loss: 0.461673] [G loss: 0.617024]
# [Epoch 5/6] [Batch 15/40] [D loss: 0.445514] [G loss: 1.036878]
# [Epoch 5/6] [Batch 16/40] [D loss: 0.320810] [G loss: 0.887992]
# [Epoch 5/6] [Batch 17/40] [D loss: 0.408610] [G loss: 0.952563]
# [Epoch 5/6] [Batch 18/40] [D loss: 0.576079] [G loss: 0.830661]
# [Epoch 5/6] [Batch 19/40] [D loss: 0.402805] [G loss: 0.726135]
# [Epoch 5/6] [Batch 20/40] [D loss: 0.346100] [G loss: 1.294630]
# [Epoch 5/6] [Batch 21/40] [D loss: 0.549589] [G loss: 1.231173]
# [Epoch 5/6] [Batch 22/40] [D loss: 0.518525] [G loss: 0.544462]
# [Epoch 5/6] [Batch 23/40] [D loss: 0.501466] [G loss: 0.563900]
# [Epoch 5/6] [Batch 24/40] [D loss: 0.351758] [G loss: 0.855591]
# [Epoch 5/6] [Batch 25/40] [D loss: 0.366075] [G loss: 1.065259]
# [Epoch 5/6] [Batch 26/40] [D loss: 0.410673] [G loss: 0.674959]
# [Epoch 5/6] [Batch 27/40] [D loss: 0.377920] [G loss: 0.778408]
# [Epoch 5/6] [Batch 28/40] [D loss: 0.281333] [G loss: 1.013841]
# [Epoch 5/6] [Batch 29/40] [D loss: 0.353344] [G loss: 1.058846]
# [Epoch 5/6] [Batch 30/40] [D loss: 0.423901] [G loss: 0.754180]
# [Epoch 5/6] [Batch 31/40] [D loss: 0.321144] [G loss: 0.844491]
# [Epoch 5/6] [Batch 32/40] [D loss: 0.402470] [G loss: 1.131726]
# [Epoch 5/6] [Batch 33/40] [D loss: 0.591134] [G loss: 0.533365]
# [Epoch 5/6] [Batch 34/40] [D loss: 0.352953] [G loss: 1.251245]
# [Epoch 5/6] [Batch 35/40] [D loss: 0.365114] [G loss: 1.176993]
# [Epoch 5/6] [Batch 36/40] [D loss: 0.481036] [G loss: 0.997381]
# [Epoch 5/6] [Batch 37/40] [D loss: 1.288443] [G loss: 2.034814]
# [Epoch 5/6] [Batch 38/40] [D loss: 2.931097] [G loss: 1.492359]
# [Epoch 5/6] [Batch 39/40] [D loss: 0.748174] [G loss: 1.078279]
# [Epoch 5/6] [Batch 40/40] [D loss: 1.175878] [G loss: 1.302248]
# [Epoch 6/6] [Batch 1/40] [D loss: 1.833522] [G loss: 0.377349]
# [Epoch 6/6] [Batch 2/40] [D loss: 0.789871] [G loss: 1.086759]
# [Epoch 6/6] [Batch 3/40] [D loss: 2.225589] [G loss: 0.203254]
# [Epoch 6/6] [Batch 4/40] [D loss: 0.579399] [G loss: 0.601390]
# [Epoch 6/6] [Batch 5/40] [D loss: 1.214619] [G loss: 1.904880]
# [Epoch 6/6] [Batch 6/40] [D loss: 1.277115] [G loss: 0.262486]
# [Epoch 6/6] [Batch 7/40] [D loss: 1.026141] [G loss: 0.315885]
# [Epoch 6/6] [Batch 8/40] [D loss: 0.543274] [G loss: 0.795453]
# [Epoch 6/6] [Batch 9/40] [D loss: 0.405144] [G loss: 1.050679]
# [Epoch 6/6] [Batch 10/40] [D loss: 0.443909] [G loss: 0.817419]
# [Epoch 6/6] [Batch 11/40] [D loss: 0.475922] [G loss: 0.640044]
# [Epoch 6/6] [Batch 12/40] [D loss: 0.491806] [G loss: 0.800899]
# [Epoch 6/6] [Batch 13/40] [D loss: 0.499421] [G loss: 0.691547]
# [Epoch 6/6] [Batch 14/40] [D loss: 0.493270] [G loss: 0.926701]
# [Epoch 6/6] [Batch 15/40] [D loss: 0.463973] [G loss: 0.994742]
# [Epoch 6/6] [Batch 16/40] [D loss: 0.427213] [G loss: 0.917478]
# [Epoch 6/6] [Batch 17/40] [D loss: 0.520022] [G loss: 0.818796]
# [Epoch 6/6] [Batch 18/40] [D loss: 0.642288] [G loss: 0.600360]
# [Epoch 6/6] [Batch 19/40] [D loss: 0.820844] [G loss: 1.238501]
# [Epoch 6/6] [Batch 20/40] [D loss: 0.973281] [G loss: 0.375095]
# [Epoch 6/6] [Batch 21/40] [D loss: 0.681335] [G loss: 0.414553]
# [Epoch 6/6] [Batch 22/40] [D loss: 0.503449] [G loss: 0.958429]
# [Epoch 6/6] [Batch 23/40] [D loss: 0.472853] [G loss: 0.786666]
# [Epoch 6/6] [Batch 24/40] [D loss: 0.425563] [G loss: 0.758752]
# [Epoch 6/6] [Batch 25/40] [D loss: 0.381955] [G loss: 0.872969]
# [Epoch 6/6] [Batch 26/40] [D loss: 0.424512] [G loss: 1.151550]
# [Epoch 6/6] [Batch 27/40] [D loss: 0.556058] [G loss: 0.658671]
# [Epoch 6/6] [Batch 28/40] [D loss: 0.402434] [G loss: 0.917404]
# [Epoch 6/6] [Batch 29/40] [D loss: 0.705919] [G loss: 0.948067]
# [Epoch 6/6] [Batch 30/40] [D loss: 0.683885] [G loss: 0.433028]
# [Epoch 6/6] [Batch 31/40] [D loss: 0.492884] [G loss: 0.596286]
# [Epoch 6/6] [Batch 32/40] [D loss: 0.532719] [G loss: 0.990383]
# [Epoch 6/6] [Batch 33/40] [D loss: 0.488593] [G loss: 0.739174]
# [Epoch 6/6] [Batch 34/40] [D loss: 0.449356] [G loss: 0.680975]
# [Epoch 6/6] [Batch 35/40] [D loss: 0.473022] [G loss: 0.892473]
# [Epoch 6/6] [Batch 36/40] [D loss: 0.420719] [G loss: 0.740040]
# [Epoch 6/6] [Batch 37/40] [D loss: 0.416418] [G loss: 0.895685]
# [Epoch 6/6] [Batch 38/40] [D loss: 0.458602] [G loss: 0.913449]
# [Epoch 6/6] [Batch 39/40] [D loss: 0.422393] [G loss: 0.732376]
# [Epoch 6/6] [Batch 40/40] [D loss: 0.347408] [G loss: 0.701181]

# %%
torch.cuda.empty_cache()
plt.plot(g_loss_it)
plt.plot(d_loss_it)

# %%
# Save trained model (optional)
torch.save(generator.state_dict(), './trained_models/generator.pt')

# %%
# Load previously trained model (optional)
generator = Generator().to(device)
generator.load_state_dict(torch.load('./trained_models/generator.pt'))
generator.eval()
# Out:
# Generator(
#   (label_emb): Embedding(8, 8)
#   (model): Sequential(
#     (0): Linear(in_features=136, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Linear(in_features=256, out_features=512, bias=True)
#     (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Linear(in_features=512, out_features=1024, bias=True)
#     (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Linear(in_features=1024, out_features=192000, bias=True)
#     (12): Tanh()
#   )
# )

# %%
# Generate & save an example of every class
classes = Variable(LongTensor(range(len(car_types))))
noise = Variable(FloatTensor(cp.random.normal(0, 1, (len(car_types), latent_size))))
gen_imgs = generator(noise, classes)
save_image(gen_imgs.data, "./examples/final.png", normalize=True)

# %%
# Caclulate FID

######### Frechet Inception distance based on implementation from https://github.com/mseitzer/pytorch-fid

def calculate_frechet_distance(distribution_1, distribution_2, eps=1e-6):
    mu1 = numpy.mean(distribution_1, axis=0)
    sigma1 = numpy.cov(distribution_1, rowvar=False)

    mu2 = numpy.mean(distribution_2, axis=0)
    sigma2 = numpy.cov(distribution_2, rowvar=False)

    """Numpy implementation of the Frechet Distance.
    The Frechet distance between two multivariate Gaussians X_1 ~ N(mu_1, C_1)
    and X_2 ~ N(mu_2, C_2) is
            d^2 = ||mu_1 - mu_2||^2 + Tr(C_1 + C_2 - 2*sqrt(C_1*C_2)).
    Stable version by Dougal J. Sutherland.
    Params:
    -- mu1   : Numpy array containing the activations of a layer of the
               inception net (like returned by the function 'get_predictions')
               for generated samples.
    -- mu2   : The sample mean over activations, precalculated on an
               representative data set.
    -- sigma1: The covariance matrix over activations for generated samples.
    -- sigma2: The covariance matrix over activations, precalculated on an
               representative data set.
    Returns:
    --   : The Frechet Distance.
    """

    mu1 = numpy.atleast_1d(mu1)
    mu2 = numpy.atleast_1d(mu2)

    sigma1 = numpy.atleast_2d(sigma1)
    sigma2 = numpy.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    # Product might be almost singular
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not numpy.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = numpy.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    # Numerical error might give slight imaginary component
    if numpy.iscomplexobj(covmean):
        if not numpy.allclose(numpy.diagonal(covmean).imag, 0, atol=1e-3):
            m = numpy.max(numpy.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = numpy.trace(covmean)

    return (diff.dot(diff) + numpy.trace(sigma1) +
            numpy.trace(sigma2) - 2 * tr_covmean)

dims = 2048 # ile wyjsc fragmentu sieci z InceptionV3
block_idx = inception.InceptionV3.BLOCK_INDEX_BY_DIM[dims]
model = inception.InceptionV3([block_idx]).to(device)

noise = Variable(FloatTensor(cp.random.normal(0, 1, (30, latent_size))))
labels = Variable(LongTensor(cp.random.randint(0, number_of_classes, 30)))
generated_imgs = generator(noise, labels)

loader = DataLoader(train_ds, 30, shuffle=True)
orig_imgs, orig_labels = iter(loader).next()
generated_dist = model(generated_imgs)[0]
orig_dist = model(orig_imgs.to(device))[0]
orig_dist = orig_dist.cpu()
generated_dist = generated_dist.cpu()
fid = calculate_frechet_distance(orig_dist.squeeze().detach().numpy(), 
                                generated_dist.squeeze().detach().numpy())

print(f'Frechet Inception Distance score: {fid}')
# Out:
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
#   0%|          | 0.00/91.2M [00:00<?, ?B/s]
# Frechet Inception Distance score: 163.62047318734818

# %%
# torch.cuda.empty_cache()
variables = discriminator,optimizer_G,optimizer_D
import gc
del variables
gc.collect()
# Out:
# 1996

# %%
# Caclulate IS
######### Inception Score based on implementation from https://github.com/sbarratt/inception-score-pytorch/blob/master/inception_score.py

def inception_score(imgs, cuda=True, batch_size=30, resize=False, splits=1):
    """Computes the inception score of the generated images imgs
    imgs -- Torch dataset of (3xHxW) numpy images normalized in the range [-1, 1]
    cuda -- whether or not to run on GPU
    batch_size -- batch size for feeding into Inception v3
    splits -- number of splits
    """
    N = len(imgs)

    assert batch_size > 0
    assert N > batch_size

    # Set up dtype
    if cuda:
        dtype = torch.cuda.FloatTensor
    else:
        if torch.cuda.is_available():
            print("WARNING: You have a CUDA device, so you should probably set cuda=True")
        dtype = torch.FloatTensor

    # Set up dataloader
    dataloader = torch.utils.data.DataLoader(imgs, batch_size=batch_size)

    # # Load inception model
    model = inception_v3(pretrained=True, transform_input=False).type(dtype)
    model.eval();

    #model = inception.InceptionV3(pretrained=True, transform_input=False).type(dtype)
    # dims = 2048
    # block_idx = inception.InceptionV3.BLOCK_INDEX_BY_DIM[dims]
    # model = inception.InceptionV3([block_idx]).to(device)

    up = nn.Upsample(size=(299, 299), mode='bilinear').type(dtype)
    def get_pred(x):
        if resize:
            x = up(x)
        x = model(x)
        print(type(x))
        return nn.functional.softmax(x).data.cpu().numpy()

    # Get predictions
    preds = numpy.zeros((N, 1000))

    for i, batch in enumerate(dataloader, 0):
        batch = batch.type(dtype)
        batchv = Variable(batch)
        batch_size_i = batch.size()[0]

        preds[i*batch_size:i*batch_size + batch_size_i] = get_pred(batchv)

    # Now compute the mean kl-div
    split_scores = []

    for k in range(splits):
        part = preds[k * (N // splits): (k+1) * (N // splits), :]
        py = numpy.mean(part, axis=0)
        scores = []
        for i in range(part.shape[0]):
            pyx = part[i, :]
            scores.append(entropy(pyx, py))
        split_scores.append(numpy.exp(numpy.mean(scores)))

    return numpy.mean(split_scores), numpy.std(split_scores)

noise = Variable(FloatTensor(cp.random.normal(0, 1, (30, latent_size))))
labels = Variable(LongTensor(cp.random.randint(0, number_of_classes, 30)))
generated_imgs = generator(noise, labels)

print ("Calculating Inception Score...")
print (inception_score(generated_imgs, cuda=True, batch_size=20, resize=True, splits=5))

# loader = DataLoader(train_ds, 30, shuffle=True)
# orig_imgs, orig_labels = iter(loader).next()
# generated_dist = model(generated_imgs)[0]
# orig_dist = model(orig_imgs.to(device))[0]
# orig_dist = orig_dist.cpu()
# generated_dist = generated_dist.cpu()
# fid = calculate_frechet_distance(orig_dist.squeeze().detach().numpy(), 
#                                 generated_dist.squeeze().detach().numpy())
# Out:
# Calculating Inception Score...
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
#   0%|          | 0.00/104M [00:00<?, ?B/s]
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# (2.5535254891643246, 0.25815975467757163)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:42: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
