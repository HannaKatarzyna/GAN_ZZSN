# %%
# !pip install pytorch-fid
# !pip install wget
# !pip install unrar
# !pip install patool
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-fid
#   Downloading pytorch-fid-0.2.1.tar.gz (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (7.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.4.1)
# Requirement already satisfied: torch>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (1.11.0+cu113)
# Requirement already satisfied: torchvision>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-fid) (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.0.1->pytorch-fid) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.2.2->pytorch-fid) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.2.2->pytorch-fid) (3.0.4)
# Building wheels for collected packages: pytorch-fid
#   Building wheel for pytorch-fid (setup.py) ... done
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.2.1-py3-none-any.whl size=14835 sha256=9adcc4f78036230a26a25e463fcfdc69909bc5961d280825936ef757c0dfc1cf
#   Stored in directory: /root/.cache/pip/wheels/24/ac/03/c5634775c8a64f702343ef5923278f8d3bb8c651debc4a6890
# Successfully built pytorch-fid
# Installing collected packages: pytorch-fid
# Successfully installed pytorch-fid-0.2.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=668d77e4c20c3a1f959ec8c3601839257488f3edeb400d551b52ce8f2295fba9
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patool
#   Downloading patool-1.12-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.2 MB/s
# Installing collected packages: patool
# Successfully installed patool-1.12

# %%
import os
import shutil
import cupy as cp
import numpy
import math
import matplotlib.pyplot as plt
import torch
from torch import optim
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.utils import make_grid, save_image
from torchvision.datasets import ImageFolder
import torchvision.transforms as T
from torch.autograd import Variable
from pytorch_fid import inception
from torchvision.models.inception import inception_v3
from PIL import Image
from scipy import linalg
from scipy.stats import entropy
import wget
import patoolib

# %%
os.mkdir('unfiltered')
data_path = r'./unfiltered'
os.mkdir('filtered')
target_path= r'./filtered'
os.mkdir('examples')
os.mkdir('trained_models')

# %%
URL = "https://drive.google.com/u/0/uc?id=1TQQuT60bddyeGBVfwNOk6nxYavxQdZJD&export=download&confirm=t" 
response = wget.download(URL, "thecarconnectionpicturedataset.rar")

# %%
patoolib.extract_archive("thecarconnectionpicturedataset.rar", outdir= "unfiltered/")
# Out:
# patool: Extracting thecarconnectionpicturedataset.rar ...
# patool: running /usr/bin/unrar x -- /content/thecarconnectionpicturedataset.rar
# patool:     with cwd='unfiltered/'
# patool: ... thecarconnectionpicturedataset.rar extracted to `unfiltered/'.
# 'unfiltered/'

# %%
listOfFiles = os.listdir(data_path)
car_types= ['Convertible','Pickup','Station Wagon','4dr','3dr','2dr','SUV','Van']  # reszta to 'nan'
car_dictionary = dict.fromkeys(car_types)
for type_of_car in car_types:
    str_match = [s for s in listOfFiles if type_of_car+"_" in s]
    car_dictionary[type_of_car] = len(str_match)
    # ponizej tworzenie folderow z posortowanymi juz zdjeciami typow, czyli tzw. klas
    os.mkdir(os.path.join(target_path,type_of_car))
    target_dir = os.path.join(target_path,type_of_car)
    for fname in str_match:
        # przenoszenie plikow do wlasciwych folderow
        shutil.move(os.path.join(data_path,fname), target_dir)

# %%
cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if cuda else torch.LongTensor

# %%
## inicjalizacja parametrow
number_of_classes = len(car_types)
number_of_epochs = 10

image_size_width = 64
image_size_height = 64
image_size=(image_size_width,image_size_height)
channels = 3 # RGB
img_shape_tuple = (channels, image_size_width, image_size_height)
img_shape = cp.array([channels, image_size_width, image_size_height])

batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)
latent_size = 128  # rozmiar wektora wejsciowego do generatora

# wybor rozmiaru kerneli dla warstaw konwolucyjnych sieci: 4, 6 lub 8
kernel_param = 8
padding_param = int((kernel_param-4)/2) +1

# wybor, ile wierszy i kolumn obrazow samochodow ma zostac wygenerowanych 
# (zestawienie w macierzy kwadratowej o rozmiarze NxN)
N=5

# konwersja obrazu do tensora z odpowiednimi warunkami 
train_ds = ImageFolder(target_path, transform=T.Compose([
    T.Resize((image_size_width,image_size_height)),
    T.ToTensor(),
    T.Normalize(*stats)]))

# zbiór treningowy
train_dl = DataLoader(train_ds, batch_size, shuffle=True)

# %%
## pokazanie przykladowego batcha ze zdjeciami samochodow

def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

show_batch(train_dl)

# %%
## klasa generatora

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            # in: latent_size x 1 x 1
            nn.ConvTranspose2d(latent_size, 512, kernel_size=kernel_param, stride=1, padding=padding_param-1, bias=False),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.01, inplace=True), 
            # out: 512 x 4 x 4

            nn.ConvTranspose2d(512, 256, kernel_size=kernel_param, stride=2, padding=padding_param, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.01, inplace=True), 
            # out: 256 x 8 x 8

            nn.ConvTranspose2d(256,128, kernel_size=kernel_param, stride=2, padding=padding_param, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.01, inplace=True), 
            # out: 128 x 16 x 16

            nn.ConvTranspose2d(128, 64, kernel_size=kernel_param, stride=2, padding=padding_param, bias=False),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.01, inplace=True), 
            # out: 64 x 32 x 32

            nn.ConvTranspose2d(64, channels, kernel_size=kernel_param, stride=2, padding=padding_param, bias=False),            
            nn.Tanh()
            # out: 3 x 64 x 64
        )

    def forward(self, noise):
        img = self.model(noise.cuda())
        return img

# %%
## klasa dyskryminatora - póki co idea skopiowana z linku 3)
class Discriminator(nn.Module):
    def __init__(self):
            super(Discriminator, self).__init__()

            self.model = nn.Sequential(
                # in: 3 x 64 x 64
                nn.Conv2d(channels, 64, kernel_size=kernel_param, stride=2, padding=padding_param, bias=False),
                nn.BatchNorm2d(64),
                nn.LeakyReLU(0.01, inplace=True),
                # out: 64 x 32 x 32

                nn.Conv2d(64, 128, kernel_size=kernel_param, stride=2, padding=padding_param, bias=False),
                nn.BatchNorm2d(128),
                nn.LeakyReLU(0.01, inplace=True),
                # out: 128 x 16 x 16

                nn.Conv2d(128, 256, kernel_size=kernel_param, stride=2, padding=padding_param, bias=False),
                nn.BatchNorm2d(256),
                nn.LeakyReLU(0.01, inplace=True),
                # out: 256 x 8 x 8

                nn.Conv2d(256, 512, kernel_size=kernel_param, stride=2, padding=padding_param, bias=False),
                nn.BatchNorm2d(512),
                nn.LeakyReLU(0.01, inplace=True),
                # out: 512 x 4 x 4

                nn.Conv2d(512, 1, kernel_size=kernel_param, stride=1, padding=padding_param-1, bias=False),
                # out: 1 x 1 x 1
                nn.Sigmoid()
            )

    def forward(self, img):
        validity = self.model(img.cuda())
        return validity

# %%
# jako funkcja straty binarna entropia krzyzowa
fun_loss = nn.BCELoss()

device=torch.device('cuda')
# inicjalizacja generatora i dyskyminatora
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# wykorzystanie algorytmu Adam do optymalizacji procesu uczenia metodą spadku gradientu
b1=0.5
b2=0.999
learning_rate=0.0002
optimizer_D = optim.Adam(discriminator.parameters(), lr=learning_rate, betas=(b1, b2))
optimizer_G = optim.Adam(generator.parameters(), lr=learning_rate, betas=(b1, b2))

# %%
def sample_image(n_row, batches_done):
    """zapisywanie obrazów wygenerowanych przez klasę generatora"""
    # losowy szum
    z = Variable(FloatTensor(cp.random.normal(0, 1, (n_row ** 2, latent_size, 1, 1))))
    # wygenerowanie obrazow
    gen_imgs = generator(z)
    save_image(gen_imgs.data, "./examples/%d.png" % batches_done, nrow=n_row, normalize=True)

# %%
# Caclulate FID finction

######### Frechet Inception distance based on implementation from https://github.com/mseitzer/pytorch-fid

def calculate_frechet_distance(distribution_1, distribution_2, eps=1e-6):
    mu1 = numpy.mean(distribution_1, axis=0)
    sigma1 = numpy.cov(distribution_1, rowvar=False)

    mu2 = numpy.mean(distribution_2, axis=0)
    sigma2 = numpy.cov(distribution_2, rowvar=False)

    """Numpy implementation of the Frechet Distance.
    The Frechet distance between two multivariate Gaussians X_1 ~ N(mu_1, C_1)
    and X_2 ~ N(mu_2, C_2) is
            d^2 = ||mu_1 - mu_2||^2 + Tr(C_1 + C_2 - 2*sqrt(C_1*C_2)).
    Stable version by Dougal J. Sutherland.
    Params:
    -- mu1   : Numpy array containing the activations of a layer of the
               inception net (like returned by the function 'get_predictions')
               for generated samples.
    -- mu2   : The sample mean over activations, precalculated on an
               representative data set.
    -- sigma1: The covariance matrix over activations for generated samples.
    -- sigma2: The covariance matrix over activations, precalculated on an
               representative data set.
    Returns:
    --   : The Frechet Distance.
    """

    mu1 = numpy.atleast_1d(mu1)
    mu2 = numpy.atleast_1d(mu2)

    sigma1 = numpy.atleast_2d(sigma1)
    sigma2 = numpy.atleast_2d(sigma2)

    assert mu1.shape == mu2.shape, \
        'Training and test mean vectors have different lengths'
    assert sigma1.shape == sigma2.shape, \
        'Training and test covariances have different dimensions'

    diff = mu1 - mu2

    # Product might be almost singular
    covmean, _ = linalg.sqrtm(sigma1.dot(sigma2), disp=False)
    if not numpy.isfinite(covmean).all():
        msg = ('fid calculation produces singular product; '
               'adding %s to diagonal of cov estimates') % eps
        print(msg)
        offset = numpy.eye(sigma1.shape[0]) * eps
        covmean = linalg.sqrtm((sigma1 + offset).dot(sigma2 + offset))

    # Numerical error might give slight imaginary component
    if numpy.iscomplexobj(covmean):
        if not numpy.allclose(numpy.diagonal(covmean).imag, 0, atol=1e-3):
            m = numpy.max(numpy.abs(covmean.imag))
            raise ValueError('Imaginary component {}'.format(m))
        covmean = covmean.real

    tr_covmean = numpy.trace(covmean)

    return (diff.dot(diff) + numpy.trace(sigma1) +
            numpy.trace(sigma2) - 2 * tr_covmean)

# %%
# Caclulate IS score
######### Inception Score based on implementation from https://github.com/sbarratt/inception-score-pytorch/blob/master/inception_score.py

def calculate_inception_score(imgs, cuda=True, batch_size=30, resize=False, splits=1):
    """Computes the inception score of the generated images imgs
    imgs -- Torch dataset of (3xHxW) numpy images normalized in the range [-1, 1]
    cuda -- whether or not to run on GPU
    batch_size -- batch size for feeding into Inception v3
    splits -- number of splits
    """
    N = len(imgs)

    assert batch_size > 0
    assert N > batch_size

    # Set up dtype
    if cuda:
        dtype = torch.cuda.FloatTensor
    else:
        if torch.cuda.is_available():
            print("WARNING: You have a CUDA device, so you should probably set cuda=True")
        dtype = torch.FloatTensor

    # Set up dataloader
    dataloader = torch.utils.data.DataLoader(imgs, batch_size=batch_size)

    # # Load inception model
    model = inception_v3(pretrained=True, transform_input=False).type(dtype)
    model.eval();

    #model = inception.InceptionV3(pretrained=True, transform_input=False).type(dtype)
    # dims = 2048
    # block_idx = inception.InceptionV3.BLOCK_INDEX_BY_DIM[dims]
    # model = inception.InceptionV3([block_idx]).to(device)

    up = nn.Upsample(size=(299, 299), mode='bilinear').type(dtype)
    def get_pred(x):
        if resize:
            x = up(x)
        x = model(x)
        return nn.functional.softmax(x).data.cpu().numpy()

    # Get predictions
    preds = numpy.zeros((N, 1000))

    for i, batch in enumerate(dataloader, 0):
        batch = batch.type(dtype)
        batchv = Variable(batch)
        batch_size_i = batch.size()[0]

        preds[i*batch_size:i*batch_size + batch_size_i] = get_pred(batchv)

    # Now compute the mean kl-div
    split_scores = []

    for k in range(splits):
        part = preds[k * (N // splits): (k+1) * (N // splits), :]
        py = numpy.mean(part, axis=0)
        scores = []
        for i in range(part.shape[0]):
            pyx = part[i, :]
            scores.append(entropy(pyx, py))
        split_scores.append(numpy.exp(numpy.mean(scores)))

    return numpy.mean(split_scores)
    #return numpy.mean(split_scores), numpy.std(split_scores)

# %%
# ----------
#  Proces uczenia
# ----------
d_loss_iteration=[]
g_loss_iteration=[]

for epoch in range(number_of_epochs):
    for i, (imgs, labels) in enumerate(train_dl):

        batch_size = imgs.shape[0]

        # tensory "prawdy" dla dyskryminatora
        valid = Variable(FloatTensor(batch_size, 1,1,1).fill_(1.0), requires_grad=False)
        fake = Variable(FloatTensor(batch_size, 1,1,1).fill_(0.0), requires_grad=False)

        # konfiguracja obrazow ze zbioru treningowego
        real_imgs = Variable(imgs.type(FloatTensor))

        # -----------------
        #  trenowanie generatora
        # -----------------

        optimizer_G.zero_grad()

        # szum dla generatora
        z = Variable(FloatTensor(cp.random.normal(0, 1, (batch_size, latent_size, 1, 1))))

        # generacja obrazow
        gen_imgs = generator(z)
        # wyliczenie straty generatora
        validity = discriminator(gen_imgs)
        g_loss = fun_loss(validity, valid)

        g_loss.backward()
        optimizer_G.step()

        # ---------------------
        #  trenowanie dyskryminatora
        # ---------------------

        optimizer_D.zero_grad()

        # strata dla realnych obrazow ze zbioru treningowego
        validity_real = discriminator(real_imgs)
        d_real_loss = fun_loss(validity_real, valid)

        # strata dla falszywych obrazow od generatora
        validity_fake = discriminator(gen_imgs.detach())
        d_fake_loss = fun_loss(validity_fake, fake)

        # calkowita straty dla dyskryminatora
        d_loss = (d_real_loss + d_fake_loss) / 2

        d_loss.backward()
        optimizer_D.step()

        print(
            "[Epoch %d/%d] [Batch %d/%d] [D loss: %f] [G loss: %f]"
            % (epoch + 1, number_of_epochs, i + 1, len(train_dl), d_loss.item(), g_loss.item())
        )

        d_loss_iteration.append(d_loss.item())
        g_loss_iteration.append(g_loss.item())

        # co 100 iteracji, zapisywanie przykladowych zdjec od generatora 
        batches_done = epoch * len(train_dl) + i
        if batches_done % 100 == 0:
            sample_image(n_row=N, batches_done=batches_done)
# Out:
# [Epoch 1/10] [Batch 1/498] [D loss: 0.708077] [G loss: 0.723877]
# [Epoch 1/10] [Batch 2/498] [D loss: 0.243141] [G loss: 1.209441]
# [Epoch 1/10] [Batch 3/498] [D loss: 0.314859] [G loss: 4.478255]
# [Epoch 1/10] [Batch 4/498] [D loss: 2.864954] [G loss: 0.003397]
# [Epoch 1/10] [Batch 5/498] [D loss: 0.069520] [G loss: 4.352942]
# [Epoch 1/10] [Batch 6/498] [D loss: 0.104112] [G loss: 3.333409]
# [Epoch 1/10] [Batch 7/498] [D loss: 0.166719] [G loss: 1.472010]
# [Epoch 1/10] [Batch 8/498] [D loss: 0.081665] [G loss: 2.899824]
# [Epoch 1/10] [Batch 9/498] [D loss: 0.199356] [G loss: 1.294155]
# [Epoch 1/10] [Batch 10/498] [D loss: 0.155686] [G loss: 6.893559]
# [Epoch 1/10] [Batch 11/498] [D loss: 0.053608] [G loss: 4.952387]
# [Epoch 1/10] [Batch 12/498] [D loss: 0.931515] [G loss: 0.173981]
# [Epoch 1/10] [Batch 13/498] [D loss: 0.237099] [G loss: 7.956867]
# [Epoch 1/10] [Batch 14/498] [D loss: 0.107700] [G loss: 7.662348]
# [Epoch 1/10] [Batch 15/498] [D loss: 0.036414] [G loss: 7.080724]
# [Epoch 1/10] [Batch 16/498] [D loss: 0.023144] [G loss: 6.489970]
# [Epoch 1/10] [Batch 17/498] [D loss: 0.016162] [G loss: 5.814188]
# [Epoch 1/10] [Batch 18/498] [D loss: 0.015503] [G loss: 4.784440]
# [Epoch 1/10] [Batch 19/498] [D loss: 0.056244] [G loss: 2.418540]
# [Epoch 1/10] [Batch 20/498] [D loss: 0.533368] [G loss: 0.441074]
# [Epoch 1/10] [Batch 21/498] [D loss: 0.153409] [G loss: 7.873807]
# [Epoch 1/10] [Batch 22/498] [D loss: 0.228604] [G loss: 7.911535]
# [Epoch 1/10] [Batch 23/498] [D loss: 0.054330] [G loss: 7.176041]
# [Epoch 1/10] [Batch 24/498] [D loss: 0.062258] [G loss: 6.246077]
# [Epoch 1/10] [Batch 25/498] [D loss: 0.037152] [G loss: 3.763228]
# [Epoch 1/10] [Batch 26/498] [D loss: 1.709764] [G loss: 0.034211]
# [Epoch 1/10] [Batch 27/498] [D loss: 0.106940] [G loss: 7.360871]
# [Epoch 1/10] [Batch 28/498] [D loss: 0.250902] [G loss: 7.462511]
# [Epoch 1/10] [Batch 29/498] [D loss: 0.052164] [G loss: 6.821537]
# [Epoch 1/10] [Batch 30/498] [D loss: 0.045101] [G loss: 6.189217]
# [Epoch 1/10] [Batch 31/498] [D loss: 0.022996] [G loss: 5.502514]
# [Epoch 1/10] [Batch 32/498] [D loss: 0.018619] [G loss: 4.731183]
# [Epoch 1/10] [Batch 33/498] [D loss: 0.024827] [G loss: 3.786011]
# [Epoch 1/10] [Batch 34/498] [D loss: 0.083053] [G loss: 2.188234]
# [Epoch 1/10] [Batch 35/498] [D loss: 0.276895] [G loss: 1.006417]
# [Epoch 1/10] [Batch 36/498] [D loss: 0.022517] [G loss: 5.966774]
# [Epoch 1/10] [Batch 37/498] [D loss: 0.143701] [G loss: 2.426692]
# [Epoch 1/10] [Batch 38/498] [D loss: 1.278183] [G loss: 0.108601]
# [Epoch 1/10] [Batch 39/498] [D loss: 1.080147] [G loss: 8.739027]
# [Epoch 1/10] [Batch 40/498] [D loss: 0.161218] [G loss: 7.431032]
# [Epoch 1/10] [Batch 41/498] [D loss: 0.078510] [G loss: 5.986382]
# [Epoch 1/10] [Batch 42/498] [D loss: 0.058249] [G loss: 4.503376]
# [Epoch 1/10] [Batch 43/498] [D loss: 0.056494] [G loss: 2.842545]
# [Epoch 1/10] [Batch 44/498] [D loss: 0.221920] [G loss: 1.116607]
# [Epoch 1/10] [Batch 45/498] [D loss: 0.125358] [G loss: 1.777249]
# [Epoch 1/10] [Batch 46/498] [D loss: 0.331299] [G loss: 0.973465]
# [Epoch 1/10] [Batch 47/498] [D loss: 0.232154] [G loss: 4.912526]
# [Epoch 1/10] [Batch 48/498] [D loss: 0.291749] [G loss: 1.701941]
# [Epoch 1/10] [Batch 49/498] [D loss: 0.173993] [G loss: 3.666444]
# [Epoch 1/10] [Batch 50/498] [D loss: 0.454955] [G loss: 0.683684]
# [Epoch 1/10] [Batch 51/498] [D loss: 0.260435] [G loss: 7.887040]
# [Epoch 1/10] [Batch 52/498] [D loss: 0.093387] [G loss: 7.429994]
# [Epoch 1/10] [Batch 53/498] [D loss: 0.046038] [G loss: 5.702430]
# [Epoch 1/10] [Batch 54/498] [D loss: 0.353294] [G loss: 0.875283]
# [Epoch 1/10] [Batch 55/498] [D loss: 0.096952] [G loss: 7.130787]
# [Epoch 1/10] [Batch 56/498] [D loss: 0.142897] [G loss: 7.328514]
# [Epoch 1/10] [Batch 57/498] [D loss: 0.043473] [G loss: 6.038927]
# [Epoch 1/10] [Batch 58/498] [D loss: 0.086175] [G loss: 2.389319]
# [Epoch 1/10] [Batch 59/498] [D loss: 1.021955] [G loss: 0.169565]
# [Epoch 1/10] [Batch 60/498] [D loss: 1.568987] [G loss: 7.496351]
# [Epoch 1/10] [Batch 61/498] [D loss: 0.375864] [G loss: 6.210778]
# [Epoch 1/10] [Batch 62/498] [D loss: 0.060402] [G loss: 4.613139]
# [Epoch 1/10] [Batch 63/498] [D loss: 0.058726] [G loss: 3.486131]
# [Epoch 1/10] [Batch 64/498] [D loss: 0.076006] [G loss: 2.435743]
# [Epoch 1/10] [Batch 65/498] [D loss: 0.212646] [G loss: 1.330403]
# [Epoch 1/10] [Batch 66/498] [D loss: 0.219895] [G loss: 1.409454]
# [Epoch 1/10] [Batch 67/498] [D loss: 0.125603] [G loss: 3.210454]
# [Epoch 1/10] [Batch 68/498] [D loss: 0.281046] [G loss: 1.620652]
# [Epoch 1/10] [Batch 69/498] [D loss: 0.290594] [G loss: 3.740315]
# [Epoch 1/10] [Batch 70/498] [D loss: 0.463717] [G loss: 0.721407]
# [Epoch 1/10] [Batch 71/498] [D loss: 0.266506] [G loss: 4.370691]
# [Epoch 1/10] [Batch 72/498] [D loss: 0.132357] [G loss: 2.511508]
# [Epoch 1/10] [Batch 73/498] [D loss: 0.306935] [G loss: 1.029517]
# [Epoch 1/10] [Batch 74/498] [D loss: 0.138999] [G loss: 3.833104]
# [Epoch 1/10] [Batch 75/498] [D loss: 0.143593] [G loss: 3.458510]
# [Epoch 1/10] [Batch 76/498] [D loss: 0.168981] [G loss: 1.888483]
# [Epoch 1/10] [Batch 77/498] [D loss: 0.181008] [G loss: 1.722713]
# [Epoch 1/10] [Batch 78/498] [D loss: 0.184324] [G loss: 3.224033]
# [Epoch 1/10] [Batch 79/498] [D loss: 0.154792] [G loss: 2.095616]
# [Epoch 1/10] [Batch 80/498] [D loss: 0.121794] [G loss: 1.972402]
# [Epoch 1/10] [Batch 81/498] [D loss: 0.095598] [G loss: 2.879823]
# [Epoch 1/10] [Batch 82/498] [D loss: 0.122617] [G loss: 2.364540]
# [Epoch 1/10] [Batch 83/498] [D loss: 0.116762] [G loss: 2.168433]
# [Epoch 1/10] [Batch 84/498] [D loss: 0.116487] [G loss: 2.639471]
# [Epoch 1/10] [Batch 85/498] [D loss: 0.206895] [G loss: 2.075918]
# [Epoch 1/10] [Batch 86/498] [D loss: 0.147253] [G loss: 2.401948]
# [Epoch 1/10] [Batch 87/498] [D loss: 0.156762] [G loss: 2.055221]
# [Epoch 1/10] [Batch 88/498] [D loss: 0.126832] [G loss: 1.963183]
# [Epoch 1/10] [Batch 89/498] [D loss: 0.079366] [G loss: 3.528551]
# [Epoch 1/10] [Batch 90/498] [D loss: 0.162390] [G loss: 1.844160]
# [Epoch 1/10] [Batch 91/498] [D loss: 0.181178] [G loss: 4.385955]
# [Epoch 1/10] [Batch 92/498] [D loss: 0.164157] [G loss: 1.552313]
# [Epoch 1/10] [Batch 93/498] [D loss: 0.115644] [G loss: 3.883594]
# [Epoch 1/10] [Batch 94/498] [D loss: 0.095848] [G loss: 2.701931]
# [Epoch 1/10] [Batch 95/498] [D loss: 0.121546] [G loss: 2.891607]
# [Epoch 1/10] [Batch 96/498] [D loss: 0.223139] [G loss: 1.472405]
# [Epoch 1/10] [Batch 97/498] [D loss: 0.272002] [G loss: 6.484908]
# [Epoch 1/10] [Batch 98/498] [D loss: 0.088611] [G loss: 2.576277]
# [Epoch 1/10] [Batch 99/498] [D loss: 0.552877] [G loss: 1.182608]
# [Epoch 1/10] [Batch 100/498] [D loss: 1.936926] [G loss: 7.963232]
# [Epoch 1/10] [Batch 101/498] [D loss: 0.277085] [G loss: 4.607925]
# [Epoch 1/10] [Batch 102/498] [D loss: 0.034980] [G loss: 3.788365]
# [Epoch 1/10] [Batch 103/498] [D loss: 0.177974] [G loss: 1.326326]
# [Epoch 1/10] [Batch 104/498] [D loss: 0.080284] [G loss: 2.822245]
# [Epoch 1/10] [Batch 105/498] [D loss: 0.269107] [G loss: 1.327105]
# [Epoch 1/10] [Batch 106/498] [D loss: 0.874777] [G loss: 4.348312]
# [Epoch 1/10] [Batch 107/498] [D loss: 1.902579] [G loss: 0.046695]
# [Epoch 1/10] [Batch 108/498] [D loss: 0.463605] [G loss: 4.497697]
# [Epoch 1/10] [Batch 109/498] [D loss: 0.272444] [G loss: 3.645442]
# [Epoch 1/10] [Batch 110/498] [D loss: 0.145779] [G loss: 2.020136]
# [Epoch 1/10] [Batch 111/498] [D loss: 0.151040] [G loss: 1.568203]
# [Epoch 1/10] [Batch 112/498] [D loss: 0.086705] [G loss: 2.170039]
# [Epoch 1/10] [Batch 113/498] [D loss: 0.078508] [G loss: 2.474442]
# [Epoch 1/10] [Batch 114/498] [D loss: 0.099569] [G loss: 2.224910]
# [Epoch 1/10] [Batch 115/498] [D loss: 0.127746] [G loss: 1.739975]
# [Epoch 1/10] [Batch 116/498] [D loss: 0.124703] [G loss: 1.983040]
# [Epoch 1/10] [Batch 117/498] [D loss: 0.156990] [G loss: 1.960185]
# [Epoch 1/10] [Batch 118/498] [D loss: 0.169589] [G loss: 2.116574]
# [Epoch 1/10] [Batch 119/498] [D loss: 0.161846] [G loss: 2.072983]
# [Epoch 1/10] [Batch 120/498] [D loss: 0.187331] [G loss: 2.326869]
# [Epoch 1/10] [Batch 121/498] [D loss: 0.260075] [G loss: 1.196069]
# [Epoch 1/10] [Batch 122/498] [D loss: 0.404310] [G loss: 5.169887]
# [Epoch 1/10] [Batch 123/498] [D loss: 0.252539] [G loss: 1.249449]
# [Epoch 1/10] [Batch 124/498] [D loss: 0.067058] [G loss: 3.408825]
# [Epoch 1/10] [Batch 125/498] [D loss: 0.109099] [G loss: 3.758615]
# [Epoch 1/10] [Batch 126/498] [D loss: 0.163023] [G loss: 1.802738]
# [Epoch 1/10] [Batch 127/498] [D loss: 0.279903] [G loss: 3.416394]
# [Epoch 1/10] [Batch 128/498] [D loss: 1.505397] [G loss: 0.112868]
# [Epoch 1/10] [Batch 129/498] [D loss: 1.760993] [G loss: 7.151472]
# [Epoch 1/10] [Batch 130/498] [D loss: 0.249357] [G loss: 4.966667]
# [Epoch 1/10] [Batch 131/498] [D loss: 0.074161] [G loss: 2.421708]
# [Epoch 1/10] [Batch 132/498] [D loss: 0.343540] [G loss: 0.819996]
# [Epoch 1/10] [Batch 133/498] [D loss: 0.219147] [G loss: 1.370433]
# [Epoch 1/10] [Batch 134/498] [D loss: 0.242641] [G loss: 1.514626]
# [Epoch 1/10] [Batch 135/498] [D loss: 0.397487] [G loss: 2.279593]
# [Epoch 1/10] [Batch 136/498] [D loss: 0.405965] [G loss: 1.468435]
# [Epoch 1/10] [Batch 137/498] [D loss: 0.364957] [G loss: 1.907637]
# [Epoch 1/10] [Batch 138/498] [D loss: 0.393378] [G loss: 0.933854]
# [Epoch 1/10] [Batch 139/498] [D loss: 0.309983] [G loss: 2.801527]
# [Epoch 1/10] [Batch 140/498] [D loss: 0.310453] [G loss: 1.539715]
# [Epoch 1/10] [Batch 141/498] [D loss: 0.251357] [G loss: 1.306436]
# [Epoch 1/10] [Batch 142/498] [D loss: 0.355519] [G loss: 2.057248]
# [Epoch 1/10] [Batch 143/498] [D loss: 0.692914] [G loss: 0.590113]
# [Epoch 1/10] [Batch 144/498] [D loss: 1.091253] [G loss: 5.776112]
# [Epoch 1/10] [Batch 145/498] [D loss: 0.238458] [G loss: 2.959158]
# [Epoch 1/10] [Batch 146/498] [D loss: 0.459687] [G loss: 0.728596]
# [Epoch 1/10] [Batch 147/498] [D loss: 0.160863] [G loss: 2.868429]
# [Epoch 1/10] [Batch 148/498] [D loss: 0.104392] [G loss: 3.340463]
# [Epoch 1/10] [Batch 149/498] [D loss: 0.150073] [G loss: 2.146716]
# [Epoch 1/10] [Batch 150/498] [D loss: 0.240093] [G loss: 1.577155]
# [Epoch 1/10] [Batch 151/498] [D loss: 0.202172] [G loss: 2.907299]
# [Epoch 1/10] [Batch 152/498] [D loss: 0.308269] [G loss: 1.456424]
# [Epoch 1/10] [Batch 153/498] [D loss: 0.236122] [G loss: 3.540507]
# [Epoch 1/10] [Batch 154/498] [D loss: 0.185200] [G loss: 1.570810]
# [Epoch 1/10] [Batch 155/498] [D loss: 0.137282] [G loss: 3.153934]
# [Epoch 1/10] [Batch 156/498] [D loss: 0.205552] [G loss: 1.451138]
# [Epoch 1/10] [Batch 157/498] [D loss: 0.198720] [G loss: 3.639613]
# [Epoch 1/10] [Batch 158/498] [D loss: 0.356609] [G loss: 1.094332]
# [Epoch 1/10] [Batch 159/498] [D loss: 0.374237] [G loss: 6.605617]
# [Epoch 1/10] [Batch 160/498] [D loss: 0.036318] [G loss: 5.053750]
# [Epoch 1/10] [Batch 161/498] [D loss: 0.143920] [G loss: 1.827716]
# [Epoch 1/10] [Batch 162/498] [D loss: 0.130760] [G loss: 1.722602]
# [Epoch 1/10] [Batch 163/498] [D loss: 0.107687] [G loss: 4.687699]
# [Epoch 1/10] [Batch 164/498] [D loss: 0.468464] [G loss: 0.783399]
# [Epoch 1/10] [Batch 165/498] [D loss: 0.457988] [G loss: 6.863217]
# [Epoch 1/10] [Batch 166/498] [D loss: 0.076095] [G loss: 5.649523]
# [Epoch 1/10] [Batch 167/498] [D loss: 0.044681] [G loss: 3.391832]
# [Epoch 1/10] [Batch 168/498] [D loss: 0.109980] [G loss: 1.817029]
# [Epoch 1/10] [Batch 169/498] [D loss: 0.029246] [G loss: 3.584887]
# [Epoch 1/10] [Batch 170/498] [D loss: 0.040720] [G loss: 4.062228]
# [Epoch 1/10] [Batch 171/498] [D loss: 0.036657] [G loss: 3.415158]
# [Epoch 1/10] [Batch 172/498] [D loss: 0.090558] [G loss: 2.194277]
# [Epoch 1/10] [Batch 173/498] [D loss: 0.045447] [G loss: 3.363154]
# [Epoch 1/10] [Batch 174/498] [D loss: 0.083913] [G loss: 2.824676]
# [Epoch 1/10] [Batch 175/498] [D loss: 0.109346] [G loss: 2.016225]
# [Epoch 1/10] [Batch 176/498] [D loss: 0.082904] [G loss: 3.366909]
# [Epoch 1/10] [Batch 177/498] [D loss: 0.156365] [G loss: 2.121600]
# [Epoch 1/10] [Batch 178/498] [D loss: 0.162723] [G loss: 2.238376]
# [Epoch 1/10] [Batch 179/498] [D loss: 0.202403] [G loss: 2.621457]
# [Epoch 1/10] [Batch 180/498] [D loss: 0.229238] [G loss: 1.244854]
# [Epoch 1/10] [Batch 181/498] [D loss: 0.376745] [G loss: 6.047334]
# [Epoch 1/10] [Batch 182/498] [D loss: 0.045819] [G loss: 2.909363]
# [Epoch 1/10] [Batch 183/498] [D loss: 0.554836] [G loss: 0.519415]
# [Epoch 1/10] [Batch 184/498] [D loss: 0.327667] [G loss: 6.971490]
# [Epoch 1/10] [Batch 185/498] [D loss: 0.127828] [G loss: 6.348760]
# [Epoch 1/10] [Batch 186/498] [D loss: 0.019057] [G loss: 5.252980]
# [Epoch 1/10] [Batch 187/498] [D loss: 0.015739] [G loss: 4.456859]
# [Epoch 1/10] [Batch 188/498] [D loss: 0.029253] [G loss: 3.815307]
# [Epoch 1/10] [Batch 189/498] [D loss: 0.035734] [G loss: 3.332377]
# [Epoch 1/10] [Batch 190/498] [D loss: 0.055128] [G loss: 2.883374]
# [Epoch 1/10] [Batch 191/498] [D loss: 0.068753] [G loss: 2.286002]
# [Epoch 1/10] [Batch 192/498] [D loss: 0.215613] [G loss: 1.173272]
# [Epoch 1/10] [Batch 193/498] [D loss: 0.348901] [G loss: 5.440992]
# [Epoch 1/10] [Batch 194/498] [D loss: 0.165645] [G loss: 1.534290]
# [Epoch 1/10] [Batch 195/498] [D loss: 0.115820] [G loss: 2.904214]
# [Epoch 1/10] [Batch 196/498] [D loss: 0.117033] [G loss: 2.558029]
# [Epoch 1/10] [Batch 197/498] [D loss: 0.183848] [G loss: 1.496201]
# [Epoch 1/10] [Batch 198/498] [D loss: 0.206551] [G loss: 3.395647]
# [Epoch 1/10] [Batch 199/498] [D loss: 1.026830] [G loss: 0.195066]
# [Epoch 1/10] [Batch 200/498] [D loss: 1.927867] [G loss: 7.111409]
# [Epoch 1/10] [Batch 201/498] [D loss: 0.477330] [G loss: 4.275016]
# [Epoch 1/10] [Batch 202/498] [D loss: 0.394196] [G loss: 0.908684]
# [Epoch 1/10] [Batch 203/498] [D loss: 0.284816] [G loss: 1.055088]
# [Epoch 1/10] [Batch 204/498] [D loss: 0.149050] [G loss: 2.586816]
# [Epoch 1/10] [Batch 205/498] [D loss: 0.149172] [G loss: 3.294715]
# [Epoch 1/10] [Batch 206/498] [D loss: 0.152009] [G loss: 2.085178]
# [Epoch 1/10] [Batch 207/498] [D loss: 0.119971] [G loss: 1.919681]
# [Epoch 1/10] [Batch 208/498] [D loss: 0.208554] [G loss: 2.045520]
# [Epoch 1/10] [Batch 209/498] [D loss: 0.331632] [G loss: 1.170302]
# [Epoch 1/10] [Batch 210/498] [D loss: 0.822037] [G loss: 3.492737]
# [Epoch 1/10] [Batch 211/498] [D loss: 1.342349] [G loss: 0.080081]
# [Epoch 1/10] [Batch 212/498] [D loss: 0.439692] [G loss: 3.834582]
# [Epoch 1/10] [Batch 213/498] [D loss: 0.240696] [G loss: 2.913672]
# [Epoch 1/10] [Batch 214/498] [D loss: 0.459320] [G loss: 0.831673]
# [Epoch 1/10] [Batch 215/498] [D loss: 0.321305] [G loss: 2.034539]
# [Epoch 1/10] [Batch 216/498] [D loss: 0.326476] [G loss: 1.575240]
# [Epoch 1/10] [Batch 217/498] [D loss: 0.363863] [G loss: 1.255337]
# [Epoch 1/10] [Batch 218/498] [D loss: 0.394409] [G loss: 2.043513]
# [Epoch 1/10] [Batch 219/498] [D loss: 0.351526] [G loss: 1.221629]
# [Epoch 1/10] [Batch 220/498] [D loss: 0.318461] [G loss: 2.957302]
# [Epoch 1/10] [Batch 221/498] [D loss: 0.220162] [G loss: 1.665557]
# [Epoch 1/10] [Batch 222/498] [D loss: 0.307338] [G loss: 1.298813]
# [Epoch 1/10] [Batch 223/498] [D loss: 0.381635] [G loss: 3.504906]
# [Epoch 1/10] [Batch 224/498] [D loss: 0.193776] [G loss: 1.822465]
# [Epoch 1/10] [Batch 225/498] [D loss: 0.475712] [G loss: 0.969877]
# [Epoch 1/10] [Batch 226/498] [D loss: 0.826364] [G loss: 4.908571]
# [Epoch 1/10] [Batch 227/498] [D loss: 0.240906] [G loss: 1.787414]
# [Epoch 1/10] [Batch 228/498] [D loss: 0.295266] [G loss: 1.565130]
# [Epoch 1/10] [Batch 229/498] [D loss: 0.171137] [G loss: 4.319869]
# [Epoch 1/10] [Batch 230/498] [D loss: 0.181669] [G loss: 2.309672]
# [Epoch 1/10] [Batch 231/498] [D loss: 0.683364] [G loss: 0.619651]
# [Epoch 1/10] [Batch 232/498] [D loss: 1.029117] [G loss: 7.255365]
# [Epoch 1/10] [Batch 233/498] [D loss: 0.123599] [G loss: 5.022214]
# [Epoch 1/10] [Batch 234/498] [D loss: 0.074394] [G loss: 2.451252]
# [Epoch 1/10] [Batch 235/498] [D loss: 0.109965] [G loss: 1.859187]
# [Epoch 1/10] [Batch 236/498] [D loss: 0.060249] [G loss: 2.587519]
# [Epoch 1/10] [Batch 237/498] [D loss: 0.047049] [G loss: 3.017432]
# [Epoch 1/10] [Batch 238/498] [D loss: 0.065084] [G loss: 2.757700]
# [Epoch 1/10] [Batch 239/498] [D loss: 0.069679] [G loss: 2.613144]
# [Epoch 1/10] [Batch 240/498] [D loss: 0.111206] [G loss: 2.505992]
# [Epoch 1/10] [Batch 241/498] [D loss: 0.116378] [G loss: 2.209089]
# [Epoch 1/10] [Batch 242/498] [D loss: 0.110635] [G loss: 2.252278]
# [Epoch 1/10] [Batch 243/498] [D loss: 0.110328] [G loss: 3.034857]
# [Epoch 1/10] [Batch 244/498] [D loss: 0.072607] [G loss: 3.048423]
# [Epoch 1/10] [Batch 245/498] [D loss: 0.080534] [G loss: 3.015753]
# [Epoch 1/10] [Batch 246/498] [D loss: 0.085215] [G loss: 2.910583]
# [Epoch 1/10] [Batch 247/498] [D loss: 0.074002] [G loss: 2.629524]
# [Epoch 1/10] [Batch 248/498] [D loss: 0.058938] [G loss: 2.733988]
# [Epoch 1/10] [Batch 249/498] [D loss: 0.041192] [G loss: 3.087761]
# [Epoch 1/10] [Batch 250/498] [D loss: 0.038207] [G loss: 3.468787]
# [Epoch 1/10] [Batch 251/498] [D loss: 0.051027] [G loss: 3.022134]
# [Epoch 1/10] [Batch 252/498] [D loss: 0.040580] [G loss: 3.485855]
# [Epoch 1/10] [Batch 253/498] [D loss: 0.087832] [G loss: 2.827111]
# [Epoch 1/10] [Batch 254/498] [D loss: 0.075498] [G loss: 2.410554]
# [Epoch 1/10] [Batch 255/498] [D loss: 0.157494] [G loss: 1.615609]
# [Epoch 1/10] [Batch 256/498] [D loss: 0.205816] [G loss: 4.443935]
# [Epoch 1/10] [Batch 257/498] [D loss: 0.223212] [G loss: 1.395967]
# [Epoch 1/10] [Batch 258/498] [D loss: 0.210225] [G loss: 5.281823]
# [Epoch 1/10] [Batch 259/498] [D loss: 0.151470] [G loss: 2.216523]
# [Epoch 1/10] [Batch 260/498] [D loss: 0.135943] [G loss: 2.195348]
# [Epoch 1/10] [Batch 261/498] [D loss: 0.204525] [G loss: 4.140639]
# [Epoch 1/10] [Batch 262/498] [D loss: 0.293910] [G loss: 1.195308]
# [Epoch 1/10] [Batch 263/498] [D loss: 0.326434] [G loss: 5.653610]
# [Epoch 1/10] [Batch 264/498] [D loss: 0.073127] [G loss: 2.880727]
# [Epoch 1/10] [Batch 265/498] [D loss: 0.114057] [G loss: 2.042827]
# [Epoch 1/10] [Batch 266/498] [D loss: 0.055051] [G loss: 3.618318]
# [Epoch 1/10] [Batch 267/498] [D loss: 0.092247] [G loss: 2.934130]
# [Epoch 1/10] [Batch 268/498] [D loss: 0.089188] [G loss: 3.081074]
# [Epoch 1/10] [Batch 269/498] [D loss: 0.156632] [G loss: 2.544160]
# [Epoch 1/10] [Batch 270/498] [D loss: 0.095693] [G loss: 2.814958]
# [Epoch 1/10] [Batch 271/498] [D loss: 0.072902] [G loss: 3.099866]
# [Epoch 1/10] [Batch 272/498] [D loss: 0.058335] [G loss: 2.730279]
# [Epoch 1/10] [Batch 273/498] [D loss: 0.067669] [G loss: 2.678808]
# [Epoch 1/10] [Batch 274/498] [D loss: 0.065803] [G loss: 3.118343]
# [Epoch 1/10] [Batch 275/498] [D loss: 0.208222] [G loss: 1.538019]
# [Epoch 1/10] [Batch 276/498] [D loss: 0.314838] [G loss: 3.537068]
# [Epoch 1/10] [Batch 277/498] [D loss: 0.435089] [G loss: 1.098479]
# [Epoch 1/10] [Batch 278/498] [D loss: 0.958337] [G loss: 5.911809]
# [Epoch 1/10] [Batch 279/498] [D loss: 0.169317] [G loss: 2.651386]
# [Epoch 1/10] [Batch 280/498] [D loss: 0.555578] [G loss: 1.011766]
# [Epoch 1/10] [Batch 281/498] [D loss: 0.359811] [G loss: 3.598528]
# [Epoch 1/10] [Batch 282/498] [D loss: 0.886684] [G loss: 0.854183]
# [Epoch 1/10] [Batch 283/498] [D loss: 1.060716] [G loss: 5.394196]
# [Epoch 1/10] [Batch 284/498] [D loss: 0.450924] [G loss: 1.728094]
# [Epoch 1/10] [Batch 285/498] [D loss: 0.474809] [G loss: 0.879047]
# [Epoch 1/10] [Batch 286/498] [D loss: 0.363939] [G loss: 2.849707]
# [Epoch 1/10] [Batch 287/498] [D loss: 0.273887] [G loss: 1.407461]
# [Epoch 1/10] [Batch 288/498] [D loss: 0.308717] [G loss: 1.789053]
# [Epoch 1/10] [Batch 289/498] [D loss: 0.250415] [G loss: 1.873338]
# [Epoch 1/10] [Batch 290/498] [D loss: 0.229376] [G loss: 2.466292]
# [Epoch 1/10] [Batch 291/498] [D loss: 0.321968] [G loss: 1.448853]
# [Epoch 1/10] [Batch 292/498] [D loss: 0.248796] [G loss: 3.165552]
# [Epoch 1/10] [Batch 293/498] [D loss: 0.932434] [G loss: 0.329123]
# [Epoch 1/10] [Batch 294/498] [D loss: 1.725225] [G loss: 6.267029]
# [Epoch 1/10] [Batch 295/498] [D loss: 0.384126] [G loss: 3.045753]
# [Epoch 1/10] [Batch 296/498] [D loss: 0.403510] [G loss: 0.872533]
# [Epoch 1/10] [Batch 297/498] [D loss: 0.215488] [G loss: 1.407287]
# [Epoch 1/10] [Batch 298/498] [D loss: 0.127613] [G loss: 2.361852]
# [Epoch 1/10] [Batch 299/498] [D loss: 0.150606] [G loss: 1.984911]
# [Epoch 1/10] [Batch 300/498] [D loss: 0.252182] [G loss: 1.515447]
# [Epoch 1/10] [Batch 301/498] [D loss: 0.322661] [G loss: 1.447077]
# [Epoch 1/10] [Batch 302/498] [D loss: 0.254004] [G loss: 1.638876]
# [Epoch 1/10] [Batch 303/498] [D loss: 0.343507] [G loss: 1.943276]
# [Epoch 1/10] [Batch 304/498] [D loss: 0.435571] [G loss: 0.925733]
# [Epoch 1/10] [Batch 305/498] [D loss: 0.363696] [G loss: 4.797231]
# [Epoch 1/10] [Batch 306/498] [D loss: 0.148994] [G loss: 1.938974]
# [Epoch 1/10] [Batch 307/498] [D loss: 0.231475] [G loss: 1.407246]
# [Epoch 1/10] [Batch 308/498] [D loss: 0.166415] [G loss: 4.671175]
# [Epoch 1/10] [Batch 309/498] [D loss: 0.084611] [G loss: 4.587509]
# [Epoch 1/10] [Batch 310/498] [D loss: 0.038355] [G loss: 3.956939]
# [Epoch 1/10] [Batch 311/498] [D loss: 0.045471] [G loss: 3.259108]
# [Epoch 1/10] [Batch 312/498] [D loss: 0.053882] [G loss: 3.106858]
# [Epoch 1/10] [Batch 313/498] [D loss: 0.065579] [G loss: 2.639134]
# [Epoch 1/10] [Batch 314/498] [D loss: 0.093766] [G loss: 2.479355]
# [Epoch 1/10] [Batch 315/498] [D loss: 0.161223] [G loss: 2.067959]
# [Epoch 1/10] [Batch 316/498] [D loss: 0.307143] [G loss: 1.627374]
# [Epoch 1/10] [Batch 317/498] [D loss: 0.289567] [G loss: 1.897579]
# [Epoch 1/10] [Batch 318/498] [D loss: 0.239203] [G loss: 1.861380]
# [Epoch 1/10] [Batch 319/498] [D loss: 0.417120] [G loss: 3.774573]
# [Epoch 1/10] [Batch 320/498] [D loss: 1.097358] [G loss: 0.172091]
# [Epoch 1/10] [Batch 321/498] [D loss: 1.606344] [G loss: 7.239575]
# [Epoch 1/10] [Batch 322/498] [D loss: 0.214009] [G loss: 4.103422]
# [Epoch 1/10] [Batch 323/498] [D loss: 0.200426] [G loss: 1.317207]
# [Epoch 1/10] [Batch 324/498] [D loss: 0.228646] [G loss: 1.106796]
# [Epoch 1/10] [Batch 325/498] [D loss: 0.130571] [G loss: 1.701179]
# [Epoch 1/10] [Batch 326/498] [D loss: 0.164417] [G loss: 1.853345]
# [Epoch 1/10] [Batch 327/498] [D loss: 0.252609] [G loss: 1.595556]
# [Epoch 1/10] [Batch 328/498] [D loss: 0.306642] [G loss: 1.835972]
# [Epoch 1/10] [Batch 329/498] [D loss: 0.187370] [G loss: 2.709517]
# [Epoch 1/10] [Batch 330/498] [D loss: 0.186264] [G loss: 2.063681]
# [Epoch 1/10] [Batch 331/498] [D loss: 0.128548] [G loss: 2.387392]
# [Epoch 1/10] [Batch 332/498] [D loss: 0.195229] [G loss: 1.781294]
# [Epoch 1/10] [Batch 333/498] [D loss: 0.378106] [G loss: 1.205409]
# [Epoch 1/10] [Batch 334/498] [D loss: 0.407817] [G loss: 2.772573]
# [Epoch 1/10] [Batch 335/498] [D loss: 0.725826] [G loss: 0.342446]
# [Epoch 1/10] [Batch 336/498] [D loss: 1.200241] [G loss: 8.991585]
# [Epoch 1/10] [Batch 337/498] [D loss: 0.312556] [G loss: 6.481844]
# [Epoch 1/10] [Batch 338/498] [D loss: 0.150310] [G loss: 1.626069]
# [Epoch 1/10] [Batch 339/498] [D loss: 0.692763] [G loss: 0.344006]
# [Epoch 1/10] [Batch 340/498] [D loss: 0.287308] [G loss: 4.746087]
# [Epoch 1/10] [Batch 341/498] [D loss: 0.314385] [G loss: 4.037879]
# [Epoch 1/10] [Batch 342/498] [D loss: 0.399342] [G loss: 1.201432]
# [Epoch 1/10] [Batch 343/498] [D loss: 0.233622] [G loss: 2.783363]
# [Epoch 1/10] [Batch 344/498] [D loss: 0.191862] [G loss: 2.103505]
# [Epoch 1/10] [Batch 345/498] [D loss: 0.204929] [G loss: 1.981349]
# [Epoch 1/10] [Batch 346/498] [D loss: 0.230043] [G loss: 1.675048]
# [Epoch 1/10] [Batch 347/498] [D loss: 0.211701] [G loss: 2.411230]
# [Epoch 1/10] [Batch 348/498] [D loss: 0.245327] [G loss: 1.562830]
# [Epoch 1/10] [Batch 349/498] [D loss: 0.159396] [G loss: 2.686278]
# [Epoch 1/10] [Batch 350/498] [D loss: 0.313143] [G loss: 1.246426]
# [Epoch 1/10] [Batch 351/498] [D loss: 0.222372] [G loss: 4.010675]
# [Epoch 1/10] [Batch 352/498] [D loss: 0.248935] [G loss: 1.478432]
# [Epoch 1/10] [Batch 353/498] [D loss: 0.240006] [G loss: 3.933764]
# [Epoch 1/10] [Batch 354/498] [D loss: 0.119551] [G loss: 4.434279]
# [Epoch 1/10] [Batch 355/498] [D loss: 0.194952] [G loss: 1.653630]
# [Epoch 1/10] [Batch 356/498] [D loss: 0.119134] [G loss: 3.782629]
# [Epoch 1/10] [Batch 357/498] [D loss: 0.113561] [G loss: 2.989821]
# [Epoch 1/10] [Batch 358/498] [D loss: 0.110172] [G loss: 3.447902]
# [Epoch 1/10] [Batch 359/498] [D loss: 0.199368] [G loss: 1.377949]
# [Epoch 1/10] [Batch 360/498] [D loss: 0.392545] [G loss: 6.387157]
# [Epoch 1/10] [Batch 361/498] [D loss: 0.137604] [G loss: 2.028285]
# [Epoch 1/10] [Batch 362/498] [D loss: 0.111076] [G loss: 2.271734]
# [Epoch 1/10] [Batch 363/498] [D loss: 0.300869] [G loss: 1.829920]
# [Epoch 1/10] [Batch 364/498] [D loss: 0.247516] [G loss: 2.085987]
# [Epoch 1/10] [Batch 365/498] [D loss: 0.200932] [G loss: 1.768686]
# [Epoch 1/10] [Batch 366/498] [D loss: 0.104120] [G loss: 4.330476]
# [Epoch 1/10] [Batch 367/498] [D loss: 0.107234] [G loss: 3.001216]
# [Epoch 1/10] [Batch 368/498] [D loss: 0.117279] [G loss: 3.546049]
# [Epoch 1/10] [Batch 369/498] [D loss: 0.041798] [G loss: 5.351369]
# [Epoch 1/10] [Batch 370/498] [D loss: 0.057165] [G loss: 4.532407]
# [Epoch 1/10] [Batch 371/498] [D loss: 0.057904] [G loss: 3.616666]
# [Epoch 1/10] [Batch 372/498] [D loss: 0.054523] [G loss: 3.258425]
# [Epoch 1/10] [Batch 373/498] [D loss: 0.057747] [G loss: 3.461298]
# [Epoch 1/10] [Batch 374/498] [D loss: 0.047702] [G loss: 3.662147]
# [Epoch 1/10] [Batch 375/498] [D loss: 0.059410] [G loss: 2.820085]
# [Epoch 1/10] [Batch 376/498] [D loss: 0.079320] [G loss: 2.811534]
# [Epoch 1/10] [Batch 377/498] [D loss: 0.136837] [G loss: 3.942962]
# [Epoch 1/10] [Batch 378/498] [D loss: 0.601685] [G loss: 0.812940]
# [Epoch 1/10] [Batch 379/498] [D loss: 2.324815] [G loss: 7.383564]
# [Epoch 1/10] [Batch 380/498] [D loss: 0.760455] [G loss: 3.038918]
# [Epoch 1/10] [Batch 381/498] [D loss: 0.306560] [G loss: 1.720952]
# [Epoch 1/10] [Batch 382/498] [D loss: 0.262677] [G loss: 2.014982]
# [Epoch 1/10] [Batch 383/498] [D loss: 0.124065] [G loss: 3.094523]
# [Epoch 1/10] [Batch 384/498] [D loss: 0.161240] [G loss: 2.812283]
# [Epoch 1/10] [Batch 385/498] [D loss: 0.137484] [G loss: 2.162986]
# [Epoch 1/10] [Batch 386/498] [D loss: 0.173976] [G loss: 2.081910]
# [Epoch 1/10] [Batch 387/498] [D loss: 0.253785] [G loss: 1.786931]
# [Epoch 1/10] [Batch 388/498] [D loss: 0.229193] [G loss: 2.076826]
# [Epoch 1/10] [Batch 389/498] [D loss: 0.263666] [G loss: 1.397597]
# [Epoch 1/10] [Batch 390/498] [D loss: 0.344303] [G loss: 3.608043]
# [Epoch 1/10] [Batch 391/498] [D loss: 0.373003] [G loss: 0.884120]
# [Epoch 1/10] [Batch 392/498] [D loss: 0.191025] [G loss: 4.246623]
# [Epoch 1/10] [Batch 393/498] [D loss: 0.120024] [G loss: 3.069838]
# [Epoch 1/10] [Batch 394/498] [D loss: 0.692400] [G loss: 0.649409]
# [Epoch 1/10] [Batch 395/498] [D loss: 0.791431] [G loss: 7.142473]
# [Epoch 1/10] [Batch 396/498] [D loss: 0.228841] [G loss: 5.602751]
# [Epoch 1/10] [Batch 397/498] [D loss: 0.289048] [G loss: 2.734476]
# [Epoch 1/10] [Batch 398/498] [D loss: 0.543252] [G loss: 2.031277]
# [Epoch 1/10] [Batch 399/498] [D loss: 0.398294] [G loss: 6.060395]
# [Epoch 1/10] [Batch 400/498] [D loss: 0.219824] [G loss: 3.643087]
# [Epoch 1/10] [Batch 401/498] [D loss: 0.088964] [G loss: 3.186806]
# [Epoch 1/10] [Batch 402/498] [D loss: 0.164501] [G loss: 1.852021]
# [Epoch 1/10] [Batch 403/498] [D loss: 0.094059] [G loss: 3.153031]
# [Epoch 1/10] [Batch 404/498] [D loss: 0.112759] [G loss: 2.963516]
# [Epoch 1/10] [Batch 405/498] [D loss: 0.242463] [G loss: 1.266292]
# [Epoch 1/10] [Batch 406/498] [D loss: 0.547674] [G loss: 5.278343]
# [Epoch 1/10] [Batch 407/498] [D loss: 0.727518] [G loss: 0.359538]
# [Epoch 1/10] [Batch 408/498] [D loss: 0.712567] [G loss: 6.809326]
# [Epoch 1/10] [Batch 409/498] [D loss: 0.162154] [G loss: 4.645670]
# [Epoch 1/10] [Batch 410/498] [D loss: 0.322718] [G loss: 1.035550]
# [Epoch 1/10] [Batch 411/498] [D loss: 0.169894] [G loss: 2.114571]
# [Epoch 1/10] [Batch 412/498] [D loss: 0.123986] [G loss: 2.760566]
# [Epoch 1/10] [Batch 413/498] [D loss: 0.225700] [G loss: 1.660463]
# [Epoch 1/10] [Batch 414/498] [D loss: 0.207242] [G loss: 2.360745]
# [Epoch 1/10] [Batch 415/498] [D loss: 0.289465] [G loss: 2.112326]
# [Epoch 1/10] [Batch 416/498] [D loss: 0.303845] [G loss: 1.429162]
# [Epoch 1/10] [Batch 417/498] [D loss: 0.332610] [G loss: 4.853281]
# [Epoch 1/10] [Batch 418/498] [D loss: 0.304876] [G loss: 1.233868]
# [Epoch 1/10] [Batch 419/498] [D loss: 0.172116] [G loss: 4.531959]
# [Epoch 1/10] [Batch 420/498] [D loss: 0.148810] [G loss: 2.001814]
# [Epoch 1/10] [Batch 421/498] [D loss: 0.574794] [G loss: 0.571249]
# [Epoch 1/10] [Batch 422/498] [D loss: 1.310813] [G loss: 7.063345]
# [Epoch 1/10] [Batch 423/498] [D loss: 0.457939] [G loss: 2.746657]
# [Epoch 1/10] [Batch 424/498] [D loss: 0.619891] [G loss: 0.662674]
# [Epoch 1/10] [Batch 425/498] [D loss: 0.185095] [G loss: 3.760911]
# [Epoch 1/10] [Batch 426/498] [D loss: 0.139208] [G loss: 3.930614]
# [Epoch 1/10] [Batch 427/498] [D loss: 0.216029] [G loss: 1.583415]
# [Epoch 1/10] [Batch 428/498] [D loss: 0.216642] [G loss: 1.756358]
# [Epoch 1/10] [Batch 429/498] [D loss: 0.204690] [G loss: 2.781471]
# [Epoch 1/10] [Batch 430/498] [D loss: 0.171808] [G loss: 1.880972]
# [Epoch 1/10] [Batch 431/498] [D loss: 0.146684] [G loss: 2.116999]
# [Epoch 1/10] [Batch 432/498] [D loss: 0.141082] [G loss: 2.218548]
# [Epoch 1/10] [Batch 433/498] [D loss: 0.163614] [G loss: 2.355716]
# [Epoch 1/10] [Batch 434/498] [D loss: 0.153434] [G loss: 1.853832]
# [Epoch 1/10] [Batch 435/498] [D loss: 0.096511] [G loss: 3.494064]
# [Epoch 1/10] [Batch 436/498] [D loss: 0.129123] [G loss: 2.433880]
# [Epoch 1/10] [Batch 437/498] [D loss: 0.134812] [G loss: 2.068634]
# [Epoch 1/10] [Batch 438/498] [D loss: 0.098871] [G loss: 3.152444]
# [Epoch 1/10] [Batch 439/498] [D loss: 0.256047] [G loss: 1.370961]
# [Epoch 1/10] [Batch 440/498] [D loss: 0.676092] [G loss: 5.881289]
# [Epoch 1/10] [Batch 441/498] [D loss: 0.628233] [G loss: 0.419297]
# [Epoch 1/10] [Batch 442/498] [D loss: 0.402008] [G loss: 6.734936]
# [Epoch 1/10] [Batch 443/498] [D loss: 0.092915] [G loss: 5.630211]
# [Epoch 1/10] [Batch 444/498] [D loss: 0.158940] [G loss: 2.243519]
# [Epoch 1/10] [Batch 445/498] [D loss: 0.580884] [G loss: 0.609057]
# [Epoch 1/10] [Batch 446/498] [D loss: 0.920500] [G loss: 6.768517]
# [Epoch 1/10] [Batch 447/498] [D loss: 0.480527] [G loss: 5.596788]
# [Epoch 1/10] [Batch 448/498] [D loss: 0.263013] [G loss: 1.848593]
# [Epoch 1/10] [Batch 449/498] [D loss: 0.210984] [G loss: 2.367485]
# [Epoch 1/10] [Batch 450/498] [D loss: 0.124342] [G loss: 2.777026]
# [Epoch 1/10] [Batch 451/498] [D loss: 0.407838] [G loss: 1.017120]
# [Epoch 1/10] [Batch 452/498] [D loss: 0.576699] [G loss: 2.434066]
# [Epoch 1/10] [Batch 453/498] [D loss: 0.640651] [G loss: 0.523409]
# [Epoch 1/10] [Batch 454/498] [D loss: 0.403047] [G loss: 4.467173]
# [Epoch 1/10] [Batch 455/498] [D loss: 0.230475] [G loss: 3.287582]
# [Epoch 1/10] [Batch 456/498] [D loss: 0.207968] [G loss: 1.759551]
# [Epoch 1/10] [Batch 457/498] [D loss: 0.155509] [G loss: 1.977672]
# [Epoch 1/10] [Batch 458/498] [D loss: 0.088791] [G loss: 2.341859]
# [Epoch 1/10] [Batch 459/498] [D loss: 0.135844] [G loss: 2.628236]
# [Epoch 1/10] [Batch 460/498] [D loss: 0.159081] [G loss: 1.883332]
# [Epoch 1/10] [Batch 461/498] [D loss: 0.131951] [G loss: 2.616327]
# [Epoch 1/10] [Batch 462/498] [D loss: 0.112037] [G loss: 2.744341]
# [Epoch 1/10] [Batch 463/498] [D loss: 0.107513] [G loss: 2.423314]
# [Epoch 1/10] [Batch 464/498] [D loss: 0.114871] [G loss: 3.363653]
# [Epoch 1/10] [Batch 465/498] [D loss: 0.118536] [G loss: 2.394191]
# [Epoch 1/10] [Batch 466/498] [D loss: 0.175986] [G loss: 3.469025]
# [Epoch 1/10] [Batch 467/498] [D loss: 0.776812] [G loss: 0.344731]
# [Epoch 1/10] [Batch 468/498] [D loss: 2.720116] [G loss: 10.311962]
# [Epoch 1/10] [Batch 469/498] [D loss: 1.251916] [G loss: 7.338031]
# [Epoch 1/10] [Batch 470/498] [D loss: 0.132028] [G loss: 2.817293]
# [Epoch 1/10] [Batch 471/498] [D loss: 0.462940] [G loss: 0.956752]
# [Epoch 1/10] [Batch 472/498] [D loss: 0.066022] [G loss: 2.648587]
# [Epoch 1/10] [Batch 473/498] [D loss: 0.091144] [G loss: 2.963620]
# [Epoch 1/10] [Batch 474/498] [D loss: 0.160866] [G loss: 2.370608]
# [Epoch 1/10] [Batch 475/498] [D loss: 0.128727] [G loss: 2.406387]
# [Epoch 1/10] [Batch 476/498] [D loss: 0.095303] [G loss: 3.009229]
# [Epoch 1/10] [Batch 477/498] [D loss: 0.163423] [G loss: 2.976057]
# [Epoch 1/10] [Batch 478/498] [D loss: 0.210197] [G loss: 1.772904]
# [Epoch 1/10] [Batch 479/498] [D loss: 0.202484] [G loss: 2.516150]
# [Epoch 1/10] [Batch 480/498] [D loss: 0.215443] [G loss: 3.148394]
# [Epoch 1/10] [Batch 481/498] [D loss: 0.129956] [G loss: 2.150346]
# [Epoch 1/10] [Batch 482/498] [D loss: 0.117686] [G loss: 2.137267]
# [Epoch 1/10] [Batch 483/498] [D loss: 0.105120] [G loss: 3.136059]
# [Epoch 1/10] [Batch 484/498] [D loss: 0.173014] [G loss: 2.109503]
# [Epoch 1/10] [Batch 485/498] [D loss: 0.122232] [G loss: 2.822002]
# [Epoch 1/10] [Batch 486/498] [D loss: 0.181533] [G loss: 1.797855]
# [Epoch 1/10] [Batch 487/498] [D loss: 0.260596] [G loss: 3.190281]
# [Epoch 1/10] [Batch 488/498] [D loss: 0.519576] [G loss: 0.609466]
# [Epoch 1/10] [Batch 489/498] [D loss: 1.390514] [G loss: 7.174813]
# [Epoch 1/10] [Batch 490/498] [D loss: 0.056877] [G loss: 4.211118]
# [Epoch 1/10] [Batch 491/498] [D loss: 0.111268] [G loss: 1.975521]
# [Epoch 1/10] [Batch 492/498] [D loss: 0.093088] [G loss: 2.051989]
# [Epoch 1/10] [Batch 493/498] [D loss: 0.064885] [G loss: 2.916088]
# [Epoch 1/10] [Batch 494/498] [D loss: 0.076757] [G loss: 3.236787]
# [Epoch 1/10] [Batch 495/498] [D loss: 0.061138] [G loss: 3.209580]
# [Epoch 1/10] [Batch 496/498] [D loss: 0.076401] [G loss: 2.672034]
# [Epoch 1/10] [Batch 497/498] [D loss: 0.104283] [G loss: 2.439748]
# [Epoch 1/10] [Batch 498/498] [D loss: 0.112507] [G loss: 2.347925]
# [Epoch 2/10] [Batch 1/498] [D loss: 0.180174] [G loss: 2.021943]
# [Epoch 2/10] [Batch 2/498] [D loss: 0.173546] [G loss: 1.749626]
# [Epoch 2/10] [Batch 3/498] [D loss: 0.178764] [G loss: 3.143799]
# [Epoch 2/10] [Batch 4/498] [D loss: 0.193875] [G loss: 1.416945]
# [Epoch 2/10] [Batch 5/498] [D loss: 0.095101] [G loss: 4.388261]
# [Epoch 2/10] [Batch 6/498] [D loss: 0.039774] [G loss: 4.529346]
# [Epoch 2/10] [Batch 7/498] [D loss: 0.051957] [G loss: 3.771818]
# [Epoch 2/10] [Batch 8/498] [D loss: 0.082787] [G loss: 2.502651]
# [Epoch 2/10] [Batch 9/498] [D loss: 0.063920] [G loss: 2.611692]
# [Epoch 2/10] [Batch 10/498] [D loss: 0.060491] [G loss: 2.866281]
# [Epoch 2/10] [Batch 11/498] [D loss: 0.159506] [G loss: 1.730363]
# [Epoch 2/10] [Batch 12/498] [D loss: 0.097801] [G loss: 3.500759]
# [Epoch 2/10] [Batch 13/498] [D loss: 0.102530] [G loss: 2.725093]
# [Epoch 2/10] [Batch 14/498] [D loss: 0.129178] [G loss: 1.853222]
# [Epoch 2/10] [Batch 15/498] [D loss: 0.160601] [G loss: 4.956344]
# [Epoch 2/10] [Batch 16/498] [D loss: 0.172105] [G loss: 1.529356]
# [Epoch 2/10] [Batch 17/498] [D loss: 0.225083] [G loss: 5.899290]
# [Epoch 2/10] [Batch 18/498] [D loss: 0.500133] [G loss: 0.598042]
# [Epoch 2/10] [Batch 19/498] [D loss: 2.099370] [G loss: 9.552934]
# [Epoch 2/10] [Batch 20/498] [D loss: 0.228191] [G loss: 4.574092]
# [Epoch 2/10] [Batch 21/498] [D loss: 0.774728] [G loss: 0.311801]
# [Epoch 2/10] [Batch 22/498] [D loss: 0.152873] [G loss: 3.361577]
# [Epoch 2/10] [Batch 23/498] [D loss: 0.167885] [G loss: 3.971747]
# [Epoch 2/10] [Batch 24/498] [D loss: 0.129812] [G loss: 2.725663]
# [Epoch 2/10] [Batch 25/498] [D loss: 0.243908] [G loss: 1.200780]
# [Epoch 2/10] [Batch 26/498] [D loss: 0.168173] [G loss: 2.329394]
# [Epoch 2/10] [Batch 27/498] [D loss: 0.236197] [G loss: 1.877167]
# [Epoch 2/10] [Batch 28/498] [D loss: 0.484771] [G loss: 1.072608]
# [Epoch 2/10] [Batch 29/498] [D loss: 0.595680] [G loss: 3.863758]
# [Epoch 2/10] [Batch 30/498] [D loss: 0.291341] [G loss: 1.319722]
# [Epoch 2/10] [Batch 31/498] [D loss: 0.188504] [G loss: 3.588387]
# [Epoch 2/10] [Batch 32/498] [D loss: 0.084702] [G loss: 4.477571]
# [Epoch 2/10] [Batch 33/498] [D loss: 0.113805] [G loss: 3.246215]
# [Epoch 2/10] [Batch 34/498] [D loss: 0.209978] [G loss: 1.377789]
# [Epoch 2/10] [Batch 35/498] [D loss: 0.109344] [G loss: 2.666770]
# [Epoch 2/10] [Batch 36/498] [D loss: 0.190522] [G loss: 2.775245]
# [Epoch 2/10] [Batch 37/498] [D loss: 0.216444] [G loss: 1.513803]
# [Epoch 2/10] [Batch 38/498] [D loss: 0.087553] [G loss: 2.998759]
# [Epoch 2/10] [Batch 39/498] [D loss: 0.078547] [G loss: 3.313013]
# [Epoch 2/10] [Batch 40/498] [D loss: 0.091363] [G loss: 2.591940]
# [Epoch 2/10] [Batch 41/498] [D loss: 0.096342] [G loss: 2.590028]
# [Epoch 2/10] [Batch 42/498] [D loss: 0.072303] [G loss: 2.778251]
# [Epoch 2/10] [Batch 43/498] [D loss: 0.085082] [G loss: 2.564183]
# [Epoch 2/10] [Batch 44/498] [D loss: 0.108831] [G loss: 3.249278]
# [Epoch 2/10] [Batch 45/498] [D loss: 0.099205] [G loss: 2.334342]
# [Epoch 2/10] [Batch 46/498] [D loss: 0.110337] [G loss: 2.753039]
# [Epoch 2/10] [Batch 47/498] [D loss: 0.154097] [G loss: 2.063657]
# [Epoch 2/10] [Batch 48/498] [D loss: 0.125383] [G loss: 3.455463]
# [Epoch 2/10] [Batch 49/498] [D loss: 0.177582] [G loss: 2.457470]
# [Epoch 2/10] [Batch 50/498] [D loss: 0.213051] [G loss: 1.562526]
# [Epoch 2/10] [Batch 51/498] [D loss: 0.147901] [G loss: 4.979375]
# [Epoch 2/10] [Batch 52/498] [D loss: 0.120058] [G loss: 1.923082]
# [Epoch 2/10] [Batch 53/498] [D loss: 0.148253] [G loss: 2.085738]
# [Epoch 2/10] [Batch 54/498] [D loss: 0.123608] [G loss: 3.559652]
# [Epoch 2/10] [Batch 55/498] [D loss: 0.339679] [G loss: 1.163671]
# [Epoch 2/10] [Batch 56/498] [D loss: 0.903423] [G loss: 7.608454]
# [Epoch 2/10] [Batch 57/498] [D loss: 0.142454] [G loss: 2.391239]
# [Epoch 2/10] [Batch 58/498] [D loss: 0.132138] [G loss: 2.703906]
# [Epoch 2/10] [Batch 59/498] [D loss: 0.042877] [G loss: 4.469960]
# [Epoch 2/10] [Batch 60/498] [D loss: 0.084771] [G loss: 3.566794]
# [Epoch 2/10] [Batch 61/498] [D loss: 0.127563] [G loss: 2.319230]
# [Epoch 2/10] [Batch 62/498] [D loss: 0.160125] [G loss: 2.904113]
# [Epoch 2/10] [Batch 63/498] [D loss: 0.189769] [G loss: 2.817669]
# [Epoch 2/10] [Batch 64/498] [D loss: 0.291125] [G loss: 1.367002]
# [Epoch 2/10] [Batch 65/498] [D loss: 0.174802] [G loss: 4.961417]
# [Epoch 2/10] [Batch 66/498] [D loss: 0.101572] [G loss: 2.825507]
# [Epoch 2/10] [Batch 67/498] [D loss: 0.243584] [G loss: 1.573254]
# [Epoch 2/10] [Batch 68/498] [D loss: 0.330413] [G loss: 5.096723]
# [Epoch 2/10] [Batch 69/498] [D loss: 0.213881] [G loss: 1.405308]
# [Epoch 2/10] [Batch 70/498] [D loss: 0.104142] [G loss: 5.365222]
# [Epoch 2/10] [Batch 71/498] [D loss: 0.103321] [G loss: 4.352040]
# [Epoch 2/10] [Batch 72/498] [D loss: 0.260544] [G loss: 1.440216]
# [Epoch 2/10] [Batch 73/498] [D loss: 0.187103] [G loss: 5.369200]
# [Epoch 2/10] [Batch 74/498] [D loss: 0.098495] [G loss: 3.392508]
# [Epoch 2/10] [Batch 75/498] [D loss: 0.131376] [G loss: 1.828837]
# [Epoch 2/10] [Batch 76/498] [D loss: 0.061037] [G loss: 4.655046]
# [Epoch 2/10] [Batch 77/498] [D loss: 0.067477] [G loss: 4.288944]
# [Epoch 2/10] [Batch 78/498] [D loss: 0.171314] [G loss: 1.580300]
# [Epoch 2/10] [Batch 79/498] [D loss: 0.209782] [G loss: 6.916116]
# [Epoch 2/10] [Batch 80/498] [D loss: 0.055607] [G loss: 3.710974]
# [Epoch 2/10] [Batch 81/498] [D loss: 0.159387] [G loss: 1.681235]
# [Epoch 2/10] [Batch 82/498] [D loss: 0.237537] [G loss: 7.473669]
# [Epoch 2/10] [Batch 83/498] [D loss: 0.042299] [G loss: 5.355839]
# [Epoch 2/10] [Batch 84/498] [D loss: 0.149097] [G loss: 2.584742]
# [Epoch 2/10] [Batch 85/498] [D loss: 0.139438] [G loss: 4.011369]
# [Epoch 2/10] [Batch 86/498] [D loss: 0.048521] [G loss: 4.447536]
# [Epoch 2/10] [Batch 87/498] [D loss: 0.077763] [G loss: 2.985127]
# [Epoch 2/10] [Batch 88/498] [D loss: 0.045989] [G loss: 3.820251]
# [Epoch 2/10] [Batch 89/498] [D loss: 0.038215] [G loss: 3.559786]
# [Epoch 2/10] [Batch 90/498] [D loss: 0.071583] [G loss: 3.141749]
# [Epoch 2/10] [Batch 91/498] [D loss: 0.069889] [G loss: 2.924686]
# [Epoch 2/10] [Batch 92/498] [D loss: 0.087584] [G loss: 2.722378]
# [Epoch 2/10] [Batch 93/498] [D loss: 0.038131] [G loss: 3.896792]
# [Epoch 2/10] [Batch 94/498] [D loss: 0.083295] [G loss: 2.735585]
# [Epoch 2/10] [Batch 95/498] [D loss: 0.059103] [G loss: 2.863149]
# [Epoch 2/10] [Batch 96/498] [D loss: 0.116693] [G loss: 2.304999]
# [Epoch 2/10] [Batch 97/498] [D loss: 0.139321] [G loss: 2.832547]
# [Epoch 2/10] [Batch 98/498] [D loss: 0.218815] [G loss: 1.407376]
# [Epoch 2/10] [Batch 99/498] [D loss: 0.954220] [G loss: 8.650806]
# [Epoch 2/10] [Batch 100/498] [D loss: 1.230015] [G loss: 0.148661]
# [Epoch 2/10] [Batch 101/498] [D loss: 1.104390] [G loss: 9.503891]
# [Epoch 2/10] [Batch 102/498] [D loss: 0.101578] [G loss: 7.130773]
# [Epoch 2/10] [Batch 103/498] [D loss: 0.036974] [G loss: 4.388811]
# [Epoch 2/10] [Batch 104/498] [D loss: 0.134697] [G loss: 1.958948]
# [Epoch 2/10] [Batch 105/498] [D loss: 0.155333] [G loss: 1.537862]
# [Epoch 2/10] [Batch 106/498] [D loss: 0.054487] [G loss: 2.766301]
# [Epoch 2/10] [Batch 107/498] [D loss: 0.069446] [G loss: 2.642335]
# [Epoch 2/10] [Batch 108/498] [D loss: 0.133881] [G loss: 2.246191]
# [Epoch 2/10] [Batch 109/498] [D loss: 0.211838] [G loss: 1.991331]
# [Epoch 2/10] [Batch 110/498] [D loss: 0.127871] [G loss: 3.037966]
# [Epoch 2/10] [Batch 111/498] [D loss: 0.150692] [G loss: 2.150856]
# [Epoch 2/10] [Batch 112/498] [D loss: 0.091003] [G loss: 2.948374]
# [Epoch 2/10] [Batch 113/498] [D loss: 0.166543] [G loss: 1.728176]
# [Epoch 2/10] [Batch 114/498] [D loss: 0.285314] [G loss: 4.138617]
# [Epoch 2/10] [Batch 115/498] [D loss: 0.560678] [G loss: 0.806939]
# [Epoch 2/10] [Batch 116/498] [D loss: 0.861741] [G loss: 8.342695]
# [Epoch 2/10] [Batch 117/498] [D loss: 0.086883] [G loss: 4.993812]
# [Epoch 2/10] [Batch 118/498] [D loss: 0.134952] [G loss: 1.956176]
# [Epoch 2/10] [Batch 119/498] [D loss: 0.187519] [G loss: 2.592304]
# [Epoch 2/10] [Batch 120/498] [D loss: 0.133321] [G loss: 2.723279]
# [Epoch 2/10] [Batch 121/498] [D loss: 0.445714] [G loss: 0.963507]
# [Epoch 2/10] [Batch 122/498] [D loss: 0.874039] [G loss: 7.515110]
# [Epoch 2/10] [Batch 123/498] [D loss: 0.347473] [G loss: 4.480781]
# [Epoch 2/10] [Batch 124/498] [D loss: 0.188578] [G loss: 2.427824]
# [Epoch 2/10] [Batch 125/498] [D loss: 0.358543] [G loss: 1.241976]
# [Epoch 2/10] [Batch 126/498] [D loss: 0.161892] [G loss: 3.630121]
# [Epoch 2/10] [Batch 127/498] [D loss: 0.269354] [G loss: 2.402683]
# [Epoch 2/10] [Batch 128/498] [D loss: 0.422365] [G loss: 1.411236]
# [Epoch 2/10] [Batch 129/498] [D loss: 0.307136] [G loss: 4.461728]
# [Epoch 2/10] [Batch 130/498] [D loss: 0.462009] [G loss: 2.396694]
# [Epoch 2/10] [Batch 131/498] [D loss: 0.238066] [G loss: 3.785582]
# [Epoch 2/10] [Batch 132/498] [D loss: 0.174058] [G loss: 3.395672]
# [Epoch 2/10] [Batch 133/498] [D loss: 0.073280] [G loss: 3.636745]
# [Epoch 2/10] [Batch 134/498] [D loss: 0.268736] [G loss: 2.144366]
# [Epoch 2/10] [Batch 135/498] [D loss: 0.213735] [G loss: 4.910706]
# [Epoch 2/10] [Batch 136/498] [D loss: 0.399384] [G loss: 2.129938]
# [Epoch 2/10] [Batch 137/498] [D loss: 0.263504] [G loss: 5.990658]
# [Epoch 2/10] [Batch 138/498] [D loss: 0.204123] [G loss: 3.091490]
# [Epoch 2/10] [Batch 139/498] [D loss: 0.119118] [G loss: 2.583199]
# [Epoch 2/10] [Batch 140/498] [D loss: 0.153943] [G loss: 2.637767]
# [Epoch 2/10] [Batch 141/498] [D loss: 0.198519] [G loss: 2.187109]
# [Epoch 2/10] [Batch 142/498] [D loss: 0.125146] [G loss: 4.966274]
# [Epoch 2/10] [Batch 143/498] [D loss: 0.093553] [G loss: 3.492301]
# [Epoch 2/10] [Batch 144/498] [D loss: 0.326483] [G loss: 1.067204]
# [Epoch 2/10] [Batch 145/498] [D loss: 0.246828] [G loss: 5.060679]
# [Epoch 2/10] [Batch 146/498] [D loss: 0.129990] [G loss: 3.099337]
# [Epoch 2/10] [Batch 147/498] [D loss: 0.372833] [G loss: 0.934702]
# [Epoch 2/10] [Batch 148/498] [D loss: 0.157500] [G loss: 4.891434]
# [Epoch 2/10] [Batch 149/498] [D loss: 0.121352] [G loss: 4.591383]
# [Epoch 2/10] [Batch 150/498] [D loss: 0.067548] [G loss: 2.530977]
# [Epoch 2/10] [Batch 151/498] [D loss: 0.125836] [G loss: 1.781544]
# [Epoch 2/10] [Batch 152/498] [D loss: 0.065627] [G loss: 3.936177]
# [Epoch 2/10] [Batch 153/498] [D loss: 0.069576] [G loss: 3.666322]
# [Epoch 2/10] [Batch 154/498] [D loss: 0.095157] [G loss: 2.330175]
# [Epoch 2/10] [Batch 155/498] [D loss: 0.092462] [G loss: 2.587967]
# [Epoch 2/10] [Batch 156/498] [D loss: 0.131100] [G loss: 2.539567]
# [Epoch 2/10] [Batch 157/498] [D loss: 0.132549] [G loss: 2.591283]
# [Epoch 2/10] [Batch 158/498] [D loss: 0.154085] [G loss: 2.542136]
# [Epoch 2/10] [Batch 159/498] [D loss: 0.265293] [G loss: 1.387953]
# [Epoch 2/10] [Batch 160/498] [D loss: 0.665742] [G loss: 6.741209]
# [Epoch 2/10] [Batch 161/498] [D loss: 0.319979] [G loss: 1.339127]
# [Epoch 2/10] [Batch 162/498] [D loss: 0.078505] [G loss: 5.172122]
# [Epoch 2/10] [Batch 163/498] [D loss: 0.124231] [G loss: 5.247040]
# [Epoch 2/10] [Batch 164/498] [D loss: 0.092910] [G loss: 2.968697]
# [Epoch 2/10] [Batch 165/498] [D loss: 0.124864] [G loss: 2.393000]
# [Epoch 2/10] [Batch 166/498] [D loss: 0.200420] [G loss: 2.014212]
# [Epoch 2/10] [Batch 167/498] [D loss: 0.421646] [G loss: 4.733967]
# [Epoch 2/10] [Batch 168/498] [D loss: 0.706889] [G loss: 0.557238]
# [Epoch 2/10] [Batch 169/498] [D loss: 0.354344] [G loss: 9.318361]
# [Epoch 2/10] [Batch 170/498] [D loss: 0.196963] [G loss: 8.797226]
# [Epoch 2/10] [Batch 171/498] [D loss: 0.050451] [G loss: 6.173311]
# [Epoch 2/10] [Batch 172/498] [D loss: 0.107044] [G loss: 3.539698]
# [Epoch 2/10] [Batch 173/498] [D loss: 0.076007] [G loss: 2.688508]
# [Epoch 2/10] [Batch 174/498] [D loss: 0.089614] [G loss: 2.863185]
# [Epoch 2/10] [Batch 175/498] [D loss: 0.069338] [G loss: 2.973338]
# [Epoch 2/10] [Batch 176/498] [D loss: 0.138895] [G loss: 2.651777]
# [Epoch 2/10] [Batch 177/498] [D loss: 0.134389] [G loss: 1.946395]
# [Epoch 2/10] [Batch 178/498] [D loss: 0.190308] [G loss: 4.089316]
# [Epoch 2/10] [Batch 179/498] [D loss: 0.207245] [G loss: 2.064919]
# [Epoch 2/10] [Batch 180/498] [D loss: 0.170099] [G loss: 3.446501]
# [Epoch 2/10] [Batch 181/498] [D loss: 0.083772] [G loss: 3.208122]
# [Epoch 2/10] [Batch 182/498] [D loss: 0.097661] [G loss: 2.555954]
# [Epoch 2/10] [Batch 183/498] [D loss: 0.176700] [G loss: 2.650791]
# [Epoch 2/10] [Batch 184/498] [D loss: 0.180707] [G loss: 2.095047]
# [Epoch 2/10] [Batch 185/498] [D loss: 0.137567] [G loss: 3.375038]
# [Epoch 2/10] [Batch 186/498] [D loss: 0.131163] [G loss: 2.370992]
# [Epoch 2/10] [Batch 187/498] [D loss: 0.143385] [G loss: 2.790142]
# [Epoch 2/10] [Batch 188/498] [D loss: 0.135620] [G loss: 1.963210]
# [Epoch 2/10] [Batch 189/498] [D loss: 0.124667] [G loss: 4.031889]
# [Epoch 2/10] [Batch 190/498] [D loss: 0.163685] [G loss: 1.827480]
# [Epoch 2/10] [Batch 191/498] [D loss: 0.197104] [G loss: 4.355033]
# [Epoch 2/10] [Batch 192/498] [D loss: 0.206744] [G loss: 1.257333]
# [Epoch 2/10] [Batch 193/498] [D loss: 0.212063] [G loss: 5.543993]
# [Epoch 2/10] [Batch 194/498] [D loss: 0.125694] [G loss: 2.570283]
# [Epoch 2/10] [Batch 195/498] [D loss: 0.072906] [G loss: 3.352226]
# [Epoch 2/10] [Batch 196/498] [D loss: 0.161046] [G loss: 2.660201]
# [Epoch 2/10] [Batch 197/498] [D loss: 0.276171] [G loss: 2.996625]
# [Epoch 2/10] [Batch 198/498] [D loss: 0.261984] [G loss: 3.939949]
# [Epoch 2/10] [Batch 199/498] [D loss: 0.107522] [G loss: 2.225149]
# [Epoch 2/10] [Batch 200/498] [D loss: 0.171399] [G loss: 5.758369]
# [Epoch 2/10] [Batch 201/498] [D loss: 0.311014] [G loss: 1.788682]
# [Epoch 2/10] [Batch 202/498] [D loss: 0.558541] [G loss: 7.480306]
# [Epoch 2/10] [Batch 203/498] [D loss: 0.585186] [G loss: 1.353622]
# [Epoch 2/10] [Batch 204/498] [D loss: 0.051734] [G loss: 6.913842]
# [Epoch 2/10] [Batch 205/498] [D loss: 0.212736] [G loss: 6.658777]
# [Epoch 2/10] [Batch 206/498] [D loss: 0.210389] [G loss: 2.320179]
# [Epoch 2/10] [Batch 207/498] [D loss: 0.125259] [G loss: 2.037343]
# [Epoch 2/10] [Batch 208/498] [D loss: 0.168252] [G loss: 2.748700]
# [Epoch 2/10] [Batch 209/498] [D loss: 0.226332] [G loss: 2.029947]
# [Epoch 2/10] [Batch 210/498] [D loss: 0.216148] [G loss: 2.237042]
# [Epoch 2/10] [Batch 211/498] [D loss: 0.212458] [G loss: 1.566035]
# [Epoch 2/10] [Batch 212/498] [D loss: 0.168884] [G loss: 4.327786]
# [Epoch 2/10] [Batch 213/498] [D loss: 0.129151] [G loss: 2.153725]
# [Epoch 2/10] [Batch 214/498] [D loss: 0.106946] [G loss: 2.499090]
# [Epoch 2/10] [Batch 215/498] [D loss: 0.107039] [G loss: 3.195422]
# [Epoch 2/10] [Batch 216/498] [D loss: 0.127853] [G loss: 2.114431]
# [Epoch 2/10] [Batch 217/498] [D loss: 0.066212] [G loss: 3.772027]
# [Epoch 2/10] [Batch 218/498] [D loss: 0.142690] [G loss: 2.466153]
# [Epoch 2/10] [Batch 219/498] [D loss: 0.139924] [G loss: 2.989561]
# [Epoch 2/10] [Batch 220/498] [D loss: 0.130001] [G loss: 2.611142]
# [Epoch 2/10] [Batch 221/498] [D loss: 0.186372] [G loss: 3.542672]
# ...
# [Epoch 10/10] [Batch 264/498] [D loss: 0.068399] [G loss: 3.719778]
# [Epoch 10/10] [Batch 265/498] [D loss: 0.017752] [G loss: 4.867144]
# [Epoch 10/10] [Batch 266/498] [D loss: 0.024710] [G loss: 4.146349]
# [Epoch 10/10] [Batch 267/498] [D loss: 0.063624] [G loss: 3.064160]
# [Epoch 10/10] [Batch 268/498] [D loss: 0.045062] [G loss: 4.375103]
# [Epoch 10/10] [Batch 269/498] [D loss: 0.084185] [G loss: 2.725498]
# [Epoch 10/10] [Batch 270/498] [D loss: 0.088067] [G loss: 5.542016]
# [Epoch 10/10] [Batch 271/498] [D loss: 0.161537] [G loss: 1.960645]
# [Epoch 10/10] [Batch 272/498] [D loss: 0.359482] [G loss: 11.839455]
# [Epoch 10/10] [Batch 273/498] [D loss: 0.152443] [G loss: 5.217433]
# [Epoch 10/10] [Batch 274/498] [D loss: 0.043318] [G loss: 7.300932]
# [Epoch 10/10] [Batch 275/498] [D loss: 0.031442] [G loss: 7.197961]
# [Epoch 10/10] [Batch 276/498] [D loss: 0.045096] [G loss: 6.044836]
# [Epoch 10/10] [Batch 277/498] [D loss: 0.059381] [G loss: 4.795854]
# [Epoch 10/10] [Batch 278/498] [D loss: 0.082516] [G loss: 3.342384]
# [Epoch 10/10] [Batch 279/498] [D loss: 0.037413] [G loss: 5.372316]
# [Epoch 10/10] [Batch 280/498] [D loss: 0.056765] [G loss: 5.284900]
# [Epoch 10/10] [Batch 281/498] [D loss: 0.089809] [G loss: 3.200483]
# [Epoch 10/10] [Batch 282/498] [D loss: 0.027814] [G loss: 4.679511]
# [Epoch 10/10] [Batch 283/498] [D loss: 0.036452] [G loss: 4.723529]
# [Epoch 10/10] [Batch 284/498] [D loss: 0.070855] [G loss: 2.754969]
# [Epoch 10/10] [Batch 285/498] [D loss: 0.118666] [G loss: 5.139168]
# [Epoch 10/10] [Batch 286/498] [D loss: 0.159632] [G loss: 2.203641]
# [Epoch 10/10] [Batch 287/498] [D loss: 0.185539] [G loss: 9.687115]
# [Epoch 10/10] [Batch 288/498] [D loss: 0.078137] [G loss: 7.638081]
# [Epoch 10/10] [Batch 289/498] [D loss: 0.006960] [G loss: 7.519555]
# [Epoch 10/10] [Batch 290/498] [D loss: 0.071092] [G loss: 6.027018]
# [Epoch 10/10] [Batch 291/498] [D loss: 0.054182] [G loss: 4.375795]
# [Epoch 10/10] [Batch 292/498] [D loss: 0.025110] [G loss: 5.374709]
# [Epoch 10/10] [Batch 293/498] [D loss: 0.028036] [G loss: 4.800184]
# [Epoch 10/10] [Batch 294/498] [D loss: 0.018758] [G loss: 4.451321]
# [Epoch 10/10] [Batch 295/498] [D loss: 0.051663] [G loss: 3.480346]
# [Epoch 10/10] [Batch 296/498] [D loss: 0.039150] [G loss: 4.675380]
# [Epoch 10/10] [Batch 297/498] [D loss: 0.046356] [G loss: 2.992397]
# [Epoch 10/10] [Batch 298/498] [D loss: 0.068729] [G loss: 5.005129]
# [Epoch 10/10] [Batch 299/498] [D loss: 0.062830] [G loss: 2.912794]
# [Epoch 10/10] [Batch 300/498] [D loss: 0.027467] [G loss: 3.790313]
# [Epoch 10/10] [Batch 301/498] [D loss: 0.044451] [G loss: 4.742408]
# [Epoch 10/10] [Batch 302/498] [D loss: 0.107529] [G loss: 2.698787]
# [Epoch 10/10] [Batch 303/498] [D loss: 0.107334] [G loss: 5.755861]
# [Epoch 10/10] [Batch 304/498] [D loss: 0.132884] [G loss: 3.350505]
# [Epoch 10/10] [Batch 305/498] [D loss: 0.020062] [G loss: 6.486263]
# [Epoch 10/10] [Batch 306/498] [D loss: 0.020623] [G loss: 6.657773]
# [Epoch 10/10] [Batch 307/498] [D loss: 0.022006] [G loss: 6.174881]
# [Epoch 10/10] [Batch 308/498] [D loss: 0.098441] [G loss: 3.206352]
# [Epoch 10/10] [Batch 309/498] [D loss: 0.128408] [G loss: 6.754457]
# [Epoch 10/10] [Batch 310/498] [D loss: 0.086054] [G loss: 2.970117]
# [Epoch 10/10] [Batch 311/498] [D loss: 0.011420] [G loss: 6.549629]
# [Epoch 10/10] [Batch 312/498] [D loss: 0.029937] [G loss: 7.507061]
# [Epoch 10/10] [Batch 313/498] [D loss: 0.026553] [G loss: 4.752186]
# [Epoch 10/10] [Batch 314/498] [D loss: 0.048412] [G loss: 3.835344]
# [Epoch 10/10] [Batch 315/498] [D loss: 0.115470] [G loss: 2.155331]
# [Epoch 10/10] [Batch 316/498] [D loss: 0.268962] [G loss: 8.827161]
# [Epoch 10/10] [Batch 317/498] [D loss: 0.026100] [G loss: 3.621469]
# [Epoch 10/10] [Batch 318/498] [D loss: 0.072181] [G loss: 2.896685]
# [Epoch 10/10] [Batch 319/498] [D loss: 0.014230] [G loss: 6.620363]
# [Epoch 10/10] [Batch 320/498] [D loss: 0.037931] [G loss: 6.870528]
# [Epoch 10/10] [Batch 321/498] [D loss: 0.043422] [G loss: 4.740305]
# [Epoch 10/10] [Batch 322/498] [D loss: 0.031865] [G loss: 4.156411]
# [Epoch 10/10] [Batch 323/498] [D loss: 0.034356] [G loss: 4.088058]
# [Epoch 10/10] [Batch 324/498] [D loss: 0.057115] [G loss: 5.139065]
# [Epoch 10/10] [Batch 325/498] [D loss: 0.267432] [G loss: 1.567575]
# [Epoch 10/10] [Batch 326/498] [D loss: 1.171795] [G loss: 14.928477]
# [Epoch 10/10] [Batch 327/498] [D loss: 0.539960] [G loss: 3.848531]
# [Epoch 10/10] [Batch 328/498] [D loss: 0.220114] [G loss: 9.546217]
# [Epoch 10/10] [Batch 329/498] [D loss: 0.153582] [G loss: 9.440815]
# [Epoch 10/10] [Batch 330/498] [D loss: 0.093003] [G loss: 6.251034]
# [Epoch 10/10] [Batch 331/498] [D loss: 0.020541] [G loss: 7.161826]
# [Epoch 10/10] [Batch 332/498] [D loss: 0.079638] [G loss: 6.536962]
# [Epoch 10/10] [Batch 333/498] [D loss: 0.051701] [G loss: 5.169324]
# [Epoch 10/10] [Batch 334/498] [D loss: 0.022872] [G loss: 5.073013]
# [Epoch 10/10] [Batch 335/498] [D loss: 0.028340] [G loss: 4.208428]
# [Epoch 10/10] [Batch 336/498] [D loss: 0.060487] [G loss: 3.813792]
# [Epoch 10/10] [Batch 337/498] [D loss: 0.090563] [G loss: 2.759650]
# [Epoch 10/10] [Batch 338/498] [D loss: 0.052769] [G loss: 4.419551]
# [Epoch 10/10] [Batch 339/498] [D loss: 0.149006] [G loss: 3.716043]
# [Epoch 10/10] [Batch 340/498] [D loss: 0.811220] [G loss: 0.397534]
# [Epoch 10/10] [Batch 341/498] [D loss: 3.622416] [G loss: 19.731018]
# [Epoch 10/10] [Batch 342/498] [D loss: 0.008363] [G loss: 10.535028]
# [Epoch 10/10] [Batch 343/498] [D loss: 0.102680] [G loss: 4.725600]
# [Epoch 10/10] [Batch 344/498] [D loss: 0.357933] [G loss: 1.952291]
# [Epoch 10/10] [Batch 345/498] [D loss: 0.026195] [G loss: 7.241635]
# [Epoch 10/10] [Batch 346/498] [D loss: 0.062060] [G loss: 8.954035]
# [Epoch 10/10] [Batch 347/498] [D loss: 0.032806] [G loss: 5.950565]
# [Epoch 10/10] [Batch 348/498] [D loss: 0.070018] [G loss: 3.105816]
# [Epoch 10/10] [Batch 349/498] [D loss: 0.054120] [G loss: 4.351068]
# [Epoch 10/10] [Batch 350/498] [D loss: 0.088459] [G loss: 4.167713]
# [Epoch 10/10] [Batch 351/498] [D loss: 0.033266] [G loss: 3.457657]
# [Epoch 10/10] [Batch 352/498] [D loss: 0.030403] [G loss: 4.142053]
# [Epoch 10/10] [Batch 353/498] [D loss: 0.064420] [G loss: 2.882476]
# [Epoch 10/10] [Batch 354/498] [D loss: 0.023450] [G loss: 5.409960]
# [Epoch 10/10] [Batch 355/498] [D loss: 0.081164] [G loss: 5.182385]
# [Epoch 10/10] [Batch 356/498] [D loss: 0.021464] [G loss: 4.643909]
# [Epoch 10/10] [Batch 357/498] [D loss: 0.085531] [G loss: 2.632769]
# [Epoch 10/10] [Batch 358/498] [D loss: 0.050700] [G loss: 4.644618]
# [Epoch 10/10] [Batch 359/498] [D loss: 0.101121] [G loss: 6.183604]
# [Epoch 10/10] [Batch 360/498] [D loss: 0.082099] [G loss: 3.608874]
# [Epoch 10/10] [Batch 361/498] [D loss: 0.046245] [G loss: 5.805994]
# [Epoch 10/10] [Batch 362/498] [D loss: 0.028465] [G loss: 5.223798]
# [Epoch 10/10] [Batch 363/498] [D loss: 0.045568] [G loss: 3.376609]
# [Epoch 10/10] [Batch 364/498] [D loss: 0.063283] [G loss: 3.654417]
# [Epoch 10/10] [Batch 365/498] [D loss: 0.054728] [G loss: 3.502081]
# [Epoch 10/10] [Batch 366/498] [D loss: 0.052448] [G loss: 3.363378]
# [Epoch 10/10] [Batch 367/498] [D loss: 0.145555] [G loss: 2.392351]
# [Epoch 10/10] [Batch 368/498] [D loss: 0.529319] [G loss: 8.009979]
# [Epoch 10/10] [Batch 369/498] [D loss: 0.349318] [G loss: 2.773528]
# [Epoch 10/10] [Batch 370/498] [D loss: 0.130974] [G loss: 10.323745]
# [Epoch 10/10] [Batch 371/498] [D loss: 0.272855] [G loss: 12.280480]
# [Epoch 10/10] [Batch 372/498] [D loss: 0.009744] [G loss: 7.993898]
# [Epoch 10/10] [Batch 373/498] [D loss: 0.122921] [G loss: 3.330722]
# [Epoch 10/10] [Batch 374/498] [D loss: 0.090811] [G loss: 5.247299]
# [Epoch 10/10] [Batch 375/498] [D loss: 0.018002] [G loss: 8.573547]
# [Epoch 10/10] [Batch 376/498] [D loss: 0.032506] [G loss: 8.518829]
# [Epoch 10/10] [Batch 377/498] [D loss: 0.037774] [G loss: 7.058244]
# [Epoch 10/10] [Batch 378/498] [D loss: 0.012856] [G loss: 5.740011]
# [Epoch 10/10] [Batch 379/498] [D loss: 0.051789] [G loss: 3.957240]
# [Epoch 10/10] [Batch 380/498] [D loss: 0.021856] [G loss: 4.967003]
# [Epoch 10/10] [Batch 381/498] [D loss: 0.119006] [G loss: 4.152683]
# [Epoch 10/10] [Batch 382/498] [D loss: 0.041837] [G loss: 3.578947]
# [Epoch 10/10] [Batch 383/498] [D loss: 0.039188] [G loss: 4.464499]
# [Epoch 10/10] [Batch 384/498] [D loss: 0.023429] [G loss: 4.541449]
# [Epoch 10/10] [Batch 385/498] [D loss: 0.091485] [G loss: 3.080687]
# [Epoch 10/10] [Batch 386/498] [D loss: 0.142239] [G loss: 3.130738]
# [Epoch 10/10] [Batch 387/498] [D loss: 0.022595] [G loss: 4.869872]
# [Epoch 10/10] [Batch 388/498] [D loss: 0.129672] [G loss: 4.445276]
# [Epoch 10/10] [Batch 389/498] [D loss: 0.152712] [G loss: 2.359751]
# [Epoch 10/10] [Batch 390/498] [D loss: 0.049066] [G loss: 7.843731]
# [Epoch 10/10] [Batch 391/498] [D loss: 0.046726] [G loss: 7.309308]
# [Epoch 10/10] [Batch 392/498] [D loss: 0.060794] [G loss: 3.957745]
# [Epoch 10/10] [Batch 393/498] [D loss: 0.237688] [G loss: 4.611091]
# [Epoch 10/10] [Batch 394/498] [D loss: 0.632929] [G loss: 0.936906]
# [Epoch 10/10] [Batch 395/498] [D loss: 0.666763] [G loss: 14.612833]
# [Epoch 10/10] [Batch 396/498] [D loss: 0.008930] [G loss: 9.891298]
# [Epoch 10/10] [Batch 397/498] [D loss: 0.025113] [G loss: 4.513630]
# [Epoch 10/10] [Batch 398/498] [D loss: 0.054065] [G loss: 3.677010]
# [Epoch 10/10] [Batch 399/498] [D loss: 0.010160] [G loss: 5.289522]
# [Epoch 10/10] [Batch 400/498] [D loss: 0.018462] [G loss: 4.603127]
# [Epoch 10/10] [Batch 401/498] [D loss: 0.023016] [G loss: 4.662309]
# [Epoch 10/10] [Batch 402/498] [D loss: 0.039861] [G loss: 3.883934]
# [Epoch 10/10] [Batch 403/498] [D loss: 0.022211] [G loss: 4.271450]
# [Epoch 10/10] [Batch 404/498] [D loss: 0.036425] [G loss: 4.645528]
# [Epoch 10/10] [Batch 405/498] [D loss: 0.103836] [G loss: 2.737214]
# [Epoch 10/10] [Batch 406/498] [D loss: 0.044011] [G loss: 3.783372]
# [Epoch 10/10] [Batch 407/498] [D loss: 0.126206] [G loss: 2.007865]
# [Epoch 10/10] [Batch 408/498] [D loss: 0.197345] [G loss: 7.799365]
# [Epoch 10/10] [Batch 409/498] [D loss: 0.113821] [G loss: 5.137618]
# [Epoch 10/10] [Batch 410/498] [D loss: 0.326667] [G loss: 1.376125]
# [Epoch 10/10] [Batch 411/498] [D loss: 0.096275] [G loss: 10.723459]
# [Epoch 10/10] [Batch 412/498] [D loss: 0.500544] [G loss: 11.777138]
# [Epoch 10/10] [Batch 413/498] [D loss: 0.079904] [G loss: 3.736436]
# [Epoch 10/10] [Batch 414/498] [D loss: 0.359343] [G loss: 1.890317]
# [Epoch 10/10] [Batch 415/498] [D loss: 0.100046] [G loss: 10.461735]
# [Epoch 10/10] [Batch 416/498] [D loss: 0.073260] [G loss: 9.217749]
# [Epoch 10/10] [Batch 417/498] [D loss: 0.072180] [G loss: 4.812187]
# [Epoch 10/10] [Batch 418/498] [D loss: 0.013420] [G loss: 4.918860]
# [Epoch 10/10] [Batch 419/498] [D loss: 0.050698] [G loss: 4.815904]
# [Epoch 10/10] [Batch 420/498] [D loss: 0.062966] [G loss: 3.555910]
# [Epoch 10/10] [Batch 421/498] [D loss: 0.035770] [G loss: 4.176667]
# [Epoch 10/10] [Batch 422/498] [D loss: 0.025338] [G loss: 3.806713]
# [Epoch 10/10] [Batch 423/498] [D loss: 0.074367] [G loss: 3.255260]
# [Epoch 10/10] [Batch 424/498] [D loss: 0.046117] [G loss: 3.603736]
# [Epoch 10/10] [Batch 425/498] [D loss: 0.036567] [G loss: 4.491444]
# [Epoch 10/10] [Batch 426/498] [D loss: 0.059447] [G loss: 2.907817]
# [Epoch 10/10] [Batch 427/498] [D loss: 0.062034] [G loss: 3.364740]
# [Epoch 10/10] [Batch 428/498] [D loss: 0.067432] [G loss: 3.470995]
# [Epoch 10/10] [Batch 429/498] [D loss: 0.049460] [G loss: 4.638552]
# [Epoch 10/10] [Batch 430/498] [D loss: 0.071853] [G loss: 2.496781]
# [Epoch 10/10] [Batch 431/498] [D loss: 0.049471] [G loss: 3.640356]
# [Epoch 10/10] [Batch 432/498] [D loss: 0.043212] [G loss: 3.575390]
# [Epoch 10/10] [Batch 433/498] [D loss: 0.145247] [G loss: 3.520102]
# [Epoch 10/10] [Batch 434/498] [D loss: 0.347334] [G loss: 0.947705]
# [Epoch 10/10] [Batch 435/498] [D loss: 0.640886] [G loss: 12.730910]
# [Epoch 10/10] [Batch 436/498] [D loss: 0.021479] [G loss: 7.568451]
# [Epoch 10/10] [Batch 437/498] [D loss: 0.141133] [G loss: 3.717206]
# [Epoch 10/10] [Batch 438/498] [D loss: 0.040734] [G loss: 4.559439]
# [Epoch 10/10] [Batch 439/498] [D loss: 0.019137] [G loss: 6.724401]
# [Epoch 10/10] [Batch 440/498] [D loss: 0.028733] [G loss: 5.622151]
# [Epoch 10/10] [Batch 441/498] [D loss: 0.052714] [G loss: 3.646656]
# [Epoch 10/10] [Batch 442/498] [D loss: 0.065473] [G loss: 3.230166]
# [Epoch 10/10] [Batch 443/498] [D loss: 0.116329] [G loss: 2.924388]
# [Epoch 10/10] [Batch 444/498] [D loss: 0.040908] [G loss: 4.402673]
# [Epoch 10/10] [Batch 445/498] [D loss: 0.091779] [G loss: 2.972768]
# [Epoch 10/10] [Batch 446/498] [D loss: 0.060198] [G loss: 4.954717]
# [Epoch 10/10] [Batch 447/498] [D loss: 0.131003] [G loss: 3.041370]
# [Epoch 10/10] [Batch 448/498] [D loss: 0.042873] [G loss: 5.772904]
# [Epoch 10/10] [Batch 449/498] [D loss: 0.100313] [G loss: 4.610928]
# [Epoch 10/10] [Batch 450/498] [D loss: 0.087327] [G loss: 2.528134]
# [Epoch 10/10] [Batch 451/498] [D loss: 0.053895] [G loss: 5.409613]
# [Epoch 10/10] [Batch 452/498] [D loss: 0.024199] [G loss: 5.068444]
# [Epoch 10/10] [Batch 453/498] [D loss: 0.069972] [G loss: 3.508913]
# [Epoch 10/10] [Batch 454/498] [D loss: 0.068403] [G loss: 3.033858]
# [Epoch 10/10] [Batch 455/498] [D loss: 0.018253] [G loss: 4.276466]
# [Epoch 10/10] [Batch 456/498] [D loss: 0.033468] [G loss: 3.621839]
# [Epoch 10/10] [Batch 457/498] [D loss: 0.026773] [G loss: 4.407963]
# [Epoch 10/10] [Batch 458/498] [D loss: 0.080229] [G loss: 3.439751]
# [Epoch 10/10] [Batch 459/498] [D loss: 0.070402] [G loss: 2.845271]
# [Epoch 10/10] [Batch 460/498] [D loss: 0.087618] [G loss: 2.237348]
# [Epoch 10/10] [Batch 461/498] [D loss: 0.187331] [G loss: 6.645911]
# [Epoch 10/10] [Batch 462/498] [D loss: 0.076710] [G loss: 3.349536]
# [Epoch 10/10] [Batch 463/498] [D loss: 0.018763] [G loss: 4.577008]
# [Epoch 10/10] [Batch 464/498] [D loss: 0.024208] [G loss: 4.611867]
# [Epoch 10/10] [Batch 465/498] [D loss: 0.019929] [G loss: 4.726680]
# [Epoch 10/10] [Batch 466/498] [D loss: 0.072231] [G loss: 3.190603]
# [Epoch 10/10] [Batch 467/498] [D loss: 0.029286] [G loss: 3.624543]
# [Epoch 10/10] [Batch 468/498] [D loss: 0.030850] [G loss: 3.813556]
# [Epoch 10/10] [Batch 469/498] [D loss: 0.060385] [G loss: 3.601339]
# [Epoch 10/10] [Batch 470/498] [D loss: 0.108292] [G loss: 2.722595]
# [Epoch 10/10] [Batch 471/498] [D loss: 0.165758] [G loss: 4.216736]
# [Epoch 10/10] [Batch 472/498] [D loss: 0.309975] [G loss: 1.114183]
# [Epoch 10/10] [Batch 473/498] [D loss: 0.753928] [G loss: 12.364706]
# [Epoch 10/10] [Batch 474/498] [D loss: 0.047152] [G loss: 4.781758]
# [Epoch 10/10] [Batch 475/498] [D loss: 0.106175] [G loss: 3.057578]
# [Epoch 10/10] [Batch 476/498] [D loss: 0.020234] [G loss: 4.613125]
# [Epoch 10/10] [Batch 477/498] [D loss: 0.026577] [G loss: 4.705635]
# [Epoch 10/10] [Batch 478/498] [D loss: 0.030601] [G loss: 4.376752]
# [Epoch 10/10] [Batch 479/498] [D loss: 0.071068] [G loss: 3.166749]
# [Epoch 10/10] [Batch 480/498] [D loss: 0.074528] [G loss: 3.466879]
# [Epoch 10/10] [Batch 481/498] [D loss: 0.086948] [G loss: 3.248647]
# [Epoch 10/10] [Batch 482/498] [D loss: 0.155994] [G loss: 3.627857]
# [Epoch 10/10] [Batch 483/498] [D loss: 0.151472] [G loss: 2.055770]
# [Epoch 10/10] [Batch 484/498] [D loss: 0.016950] [G loss: 7.135911]
# [Epoch 10/10] [Batch 485/498] [D loss: 0.103860] [G loss: 8.313575]
# [Epoch 10/10] [Batch 486/498] [D loss: 0.030585] [G loss: 5.317449]
# [Epoch 10/10] [Batch 487/498] [D loss: 0.063162] [G loss: 2.854542]
# [Epoch 10/10] [Batch 488/498] [D loss: 0.029470] [G loss: 4.294557]
# [Epoch 10/10] [Batch 489/498] [D loss: 0.026353] [G loss: 5.187668]
# [Epoch 10/10] [Batch 490/498] [D loss: 0.082781] [G loss: 2.908008]
# [Epoch 10/10] [Batch 491/498] [D loss: 0.141414] [G loss: 3.899466]
# [Epoch 10/10] [Batch 492/498] [D loss: 0.358600] [G loss: 1.005352]
# [Epoch 10/10] [Batch 493/498] [D loss: 0.821172] [G loss: 14.591736]
# [Epoch 10/10] [Batch 494/498] [D loss: 0.006605] [G loss: 9.014811]
# [Epoch 10/10] [Batch 495/498] [D loss: 0.336957] [G loss: 3.776067]
# [Epoch 10/10] [Batch 496/498] [D loss: 0.072960] [G loss: 8.611184]
# [Epoch 10/10] [Batch 497/498] [D loss: 0.114093] [G loss: 7.443348]
# [Epoch 10/10] [Batch 498/498] [D loss: 0.081544] [G loss: 3.656527]

# %%
# rysowanie wartosci funkcji straty dla obu klas sieci
number_of_iterations=range(1,number_of_epochs*len(train_dl)+1)
plt.plot(number_of_iterations,g_loss_iteration)
plt.plot(number_of_iterations,d_loss_iteration)
plt.xlabel('iterations')
plt.ylabel('values of loss function')
plt.title('Loss function')
plt.legend(['for generator', 'for discriminator'],loc='best')

# %%
# zapisz wytrenowany model (opcjonalne)
torch.save(generator.state_dict(), './trained_models/generator.pt')

# %%
# zaladuj wytrenowany model (opcjonalne)
generator = Generator().to(device)
generator.load_state_dict(torch.load('./trained_models/generator.pt'))
generator.eval()

# %%
# ewaluacja sieci GAN
noise = Variable(FloatTensor(cp.random.normal(0, 1, (40, latent_size, 1, 1))))
generated_imgs = generator(noise)

# wyliczanie FID
dims = 2048 # ile wyjsc fragmentu sieci z InceptionV3
block_idx = inception.InceptionV3.BLOCK_INDEX_BY_DIM[dims]
model = inception.InceptionV3([block_idx]).to(device)
loader = DataLoader(train_ds, 30, shuffle=True)
orig_imgs, orig_labels = iter(loader).next()
generated_dist = model(generated_imgs)[0]
orig_dist = model(orig_imgs.to(device))[0]
orig_dist = orig_dist.cpu()
generated_dist = generated_dist.cpu()
fid = calculate_frechet_distance(orig_dist.squeeze().detach().numpy(), 
                                generated_dist.squeeze().detach().numpy())

print(f'Frechet Inception Distance score: {fid}')

# wyliczanie IS
ins = calculate_inception_score(generated_imgs, cuda=True, batch_size=30, resize=True, splits=5)
print(f'Inception Score: {ins}')
# Out:
# Downloading: "https://github.com/mseitzer/pytorch-fid/releases/download/fid_weights/pt_inception-2015-12-05-6726825d.pth" to /root/.cache/torch/hub/checkpoints/pt_inception-2015-12-05-6726825d.pth
#   0%|          | 0.00/91.2M [00:00<?, ?B/s]
# Frechet Inception Distance score: 152.9527977530957
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
#   0%|          | 0.00/104M [00:00<?, ?B/s]
# Inception Score: 2.4130886161058007
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
